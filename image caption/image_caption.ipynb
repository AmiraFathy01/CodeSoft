# %% [markdown]
# ## Import Modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import libraries i need it
import os
import pickle
import numpy as np
import string
from tqdm.notebook import tqdm
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add

# %%
# path of data
path = '/content/drive/MyDrive/image caption/images/images'
WORKING_DIR = '/content/drive/MyDrive/image caption/'

# %% [markdown]
# ## Extract Image features

# %%
# load vgg16 model
model = VGG16()
# restructure the model
model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
# summarize
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
# =================================================================
# Total params: 134260544 (512.16 MB)
# Trainable params: 134260544 (512.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# extract features from image
features = {}
directory = os.path.join(path, )

for img_name in  tqdm(os.listdir(directory)):
    # load the image from file
    img_path = directory + '/' + img_name
    image = load_img(img_path, target_size=(224, 224))
    # convert image pixels to numpy array
    image = img_to_array(image)
    # reshape data for model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    # preprocess image for vgg
    image = preprocess_input(image)
    # extract features
    feature = model.predict(image, verbose=0)
    # get image ID
    image_id = img_name.split('.')[0]
    image_id =image_id.split('_')[1]
    # store feature
    features[image_id] = feature
# Out:
#   0%|          | 0/2054 [00:00<?, ?it/s]

# %%
# store features in pickle
pickle.dump(features, open(os.path.join(WORKING_DIR, 'features.pkl'), 'wb'))

# %%
# load features from pickle
with open(os.path.join(WORKING_DIR, 'features.pkl'), 'rb') as f:
    features = pickle.load(f)

# %%
len(features)
# Out:
# 2054

# %%
features
# Out:
# {'1945': array([[0.      , 0.      , 2.084639, ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '2256': array([[2.3960452, 1.7155643, 0.       , ..., 0.       , 0.       ,
#          1.2458236]], dtype=float32),
#  '2148': array([[0.34315708, 0.50850284, 0.        , ..., 0.        , 0.        ,
#          1.4070866 ]], dtype=float32),
#  '2248': array([[2.0026598 , 1.2470307 , 0.29912555, ..., 0.        , 0.        ,
#          1.0367296 ]], dtype=float32),
#  '222': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.5714995]], dtype=float32),
#  '1837': array([[0.5759615, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.7523429]], dtype=float32),
#  '1868': array([[0.        , 0.13456464, 0.7703082 , ..., 0.        , 1.0426576 ,
#          0.        ]], dtype=float32),
#  '2217': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.08891118]], dtype=float32),
#  '2038': array([[0.        , 0.        , 2.8048196 , ..., 0.        , 0.82396424,
#          1.1693478 ]], dtype=float32),
#  '208': array([[0.        , 0.        , 0.44179034, ..., 0.        , 0.        ,
#          5.366812  ]], dtype=float32),
#  '1848': array([[2.233089  , 0.7556251 , 0.        , ..., 0.        , 0.19394083,
#          1.7673829 ]], dtype=float32),
#  '2164': array([[1.051491  , 3.5428472 , 0.        , ..., 0.        , 0.60552883,
#          0.        ]], dtype=float32),
#  '1926': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 3.402457]],
#        dtype=float32),
#  '1910': array([[0.       , 2.707913 , 2.056882 , ..., 0.       , 0.6489594,
#          0.       ]], dtype=float32),
#  '2296': array([[0.       , 1.3746254, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '207': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2269': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.2174399]], dtype=float32),
#  '2048': array([[0.        , 0.        , 2.3765259 , ..., 0.        , 0.87340486,
#          0.8782317 ]], dtype=float32),
#  '1973': array([[0.        , 0.49520203, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '199': array([[0.       , 2.4306114, 0.       , ..., 0.       , 1.8589969,
#          0.4656794]], dtype=float32),
#  '2203': array([[0.9209569, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.0288405]], dtype=float32),
#  '1919': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2261': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2132': array([[1.223774 , 0.897959 , 3.8064027, ..., 1.2894619, 0.       ,
#          0.       ]], dtype=float32),
#  '2017': array([[1.1524332, 0.       , 0.       , ..., 0.       , 2.7983801,
#          0.       ]], dtype=float32),
#  '2343': array([[0.5007268, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2145': array([[0.        , 0.        , 0.41584373, ..., 0.        , 0.        ,
#          2.4473104 ]], dtype=float32),
#  '2042': array([[0.      , 0.      , 0.      , ..., 0.      , 1.977047, 0.      ]],
#        dtype=float32),
#  '1941': array([[0.        , 0.        , 0.        , ..., 0.        , 0.12027737,
#          0.        ]], dtype=float32),
#  '184': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2058': array([[1.3666267 , 1.0436828 , 0.17531794, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2071': array([[0.71725845, 0.        , 0.35996985, ..., 0.        , 0.        ,
#          0.7697525 ]], dtype=float32),
#  '2315': array([[0.       , 0.6510236, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1845': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.39508325]], dtype=float32),
#  '1865': array([[0.24872091, 0.        , 0.        , ..., 0.        , 0.        ,
#          2.7282717 ]], dtype=float32),
#  '2277': array([[0.       , 0.       , 2.9846945, ..., 0.593305 , 0.       ,
#          3.4557903]], dtype=float32),
#  '2115': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.6758082]], dtype=float32),
#  '1982': array([[1.5404059, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '202': array([[0.       , 0.7768558, 0.       , ..., 1.2378858, 0.       ,
#          0.       ]], dtype=float32),
#  '2228': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '1921': array([[0.        , 0.36482567, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2088': array([[0.5559381, 0.       , 0.       , ..., 0.0815939, 0.344335 ,
#          0.       ]], dtype=float32),
#  '1922': array([[0.        , 2.3384886 , 0.        , ..., 1.2713797 , 1.1446877 ,
#          0.01344764]], dtype=float32),
#  '1887': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.515258]],
#        dtype=float32),
#  '2153': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.56013894]], dtype=float32),
#  '2357': array([[0.       , 0.       , 0.       , ..., 0.       , 2.6979253,
#          2.5962086]], dtype=float32),
#  '2363': array([[0.        , 2.1493287 , 0.47429708, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2347': array([[0.9297698 , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.99009436]], dtype=float32),
#  '2224': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.23688602]], dtype=float32),
#  '2135': array([[0.       , 2.0745175, 0.       , ..., 0.       , 1.4316075,
#          4.0485115]], dtype=float32),
#  '1948': array([[0.5093601, 0.       , 0.       , ..., 0.       , 5.621962 ,
#          1.779336 ]], dtype=float32),
#  '2082': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.0340414]], dtype=float32),
#  '2295': array([[0.        , 0.34453624, 0.        , ..., 0.        , 0.        ,
#          1.0412458 ]], dtype=float32),
#  '1946': array([[0.4870959 , 0.        , 0.13221717, ..., 0.        , 3.7694726 ,
#          0.        ]], dtype=float32),
#  '1898': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.1379646]], dtype=float32),
#  '1847': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2015': array([[0.        , 0.        , 0.22503534, ..., 0.        , 0.        ,
#          5.5774016 ]], dtype=float32),
#  '2053': array([[1.0135157, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1991': array([[0.       , 4.417962 , 0.       , ..., 2.1711388, 0.       ,
#          0.       ]], dtype=float32),
#  '200': array([[0.       , 0.       , 0.8384259, ..., 0.       , 0.       ,
#          2.4587324]], dtype=float32),
#  '1851': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.1493068]], dtype=float32),
#  '2188': array([[0.        , 2.542961  , 0.        , ..., 0.94340605, 2.2950885 ,
#          0.        ]], dtype=float32),
#  '1841': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.004848]],
#        dtype=float32),
#  '1866': array([[0.       , 2.0333247, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2177': array([[0.        , 0.        , 0.        , ..., 0.75462574, 0.41222078,
#          0.        ]], dtype=float32),
#  '2250': array([[0.02189106, 0.        , 0.        , ..., 0.        , 0.35042855,
#          1.6378968 ]], dtype=float32),
#  '1986': array([[1.3354645 , 0.        , 4.1994033 , ..., 0.        , 0.05019864,
#          2.2085767 ]], dtype=float32),
#  '1997': array([[0.       , 0.       , 0.       , ..., 1.0503737, 0.       ,
#          1.5853364]], dtype=float32),
#  '2274': array([[1.5875506 , 0.7390493 , 1.1320966 , ..., 0.        , 0.23028338,
#          0.        ]], dtype=float32),
#  '2063': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.5265248]], dtype=float32),
#  '2072': array([[0.        , 1.7882712 , 0.20839694, ..., 0.        , 0.4880426 ,
#          0.56437045]], dtype=float32),
#  '2120': array([[0.10952669, 0.        , 0.        , ..., 0.        , 1.483989  ,
#          1.6751165 ]], dtype=float32),
#  '1935': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2314': array([[0.        , 0.        , 0.12544155, ..., 0.59199125, 0.        ,
#          1.402061  ]], dtype=float32),
#  '2024': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 6.114999]],
#        dtype=float32),
#  '2284': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.595392]],
#        dtype=float32),
#  '2019': array([[0.      , 0.      , 0.      , ..., 0.      , 5.678916, 0.      ]],
#        dtype=float32),
#  '194': array([[0.       , 0.       , 1.4143838, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2368': array([[0.        , 0.45560125, 0.        , ..., 0.        , 3.4589725 ,
#          0.37553447]], dtype=float32),
#  '2131': array([[0.       , 0.       , 0.       , ..., 0.       , 3.5469828,
#          0.       ]], dtype=float32),
#  '204': array([[0.       , 1.2843677, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2216': array([[0.       , 2.0721948, 0.       , ..., 0.       , 0.4186001,
#          2.3173594]], dtype=float32),
#  '1885': array([[0.       , 0.       , 2.1569552, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1965': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.3060563]], dtype=float32),
#  '2051': array([[0.       , 0.       , 0.       , ..., 0.       , 1.1704476,
#          1.716414 ]], dtype=float32),
#  '2031': array([[0.       , 0.       , 0.2592293, ..., 0.       , 3.656514 ,
#          0.5456141]], dtype=float32),
#  '2195': array([[0.       , 0.       , 0.       , ..., 0.       , 2.6973903,
#          3.5746248]], dtype=float32),
#  '2064': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 5.028814]],
#        dtype=float32),
#  '1916': array([[0.17530343, 2.4674072 , 1.0996116 , ..., 0.        , 0.36015552,
#          0.        ]], dtype=float32),
#  '1849': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.8176111]], dtype=float32),
#  '236': array([[0.        , 0.14187443, 0.04211926, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2219': array([[2.5303745, 0.       , 0.       , ..., 0.       , 2.2948408,
#          1.975389 ]], dtype=float32),
#  '2253': array([[1.6971115, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.4258245]], dtype=float32),
#  '2003': array([[0.05920798, 0.        , 0.43470055, ..., 0.        , 1.9077196 ,
#          1.0461144 ]], dtype=float32),
#  '2187': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2226': array([[0.       , 1.2258132, 0.       , ..., 0.       , 2.0837693,
#          0.       ]], dtype=float32),
#  '1985': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.5106251]], dtype=float32),
#  '1934': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2123': array([[1.1666806, 2.0692914, 0.       , ..., 0.       , 0.       ,
#          1.1943333]], dtype=float32),
#  '2221': array([[1.5042019, 1.0832381, 0.       , ..., 0.       , 0.       ,
#          1.7640684]], dtype=float32),
#  '2099': array([[0.        , 0.        , 0.16647649, ..., 0.        , 2.659169  ,
#          1.3876054 ]], dtype=float32),
#  '2294': array([[1.630466  , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.04667383]], dtype=float32),
#  '1834': array([[3.2005954 , 0.67024875, 0.        , ..., 0.        , 0.        ,
#          2.933858  ]], dtype=float32),
#  '2118': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.3631146]], dtype=float32),
#  '2066': array([[0.       , 0.       , 0.       , ..., 0.       , 1.9335203,
#          1.3917441]], dtype=float32),
#  '1904': array([[0.        , 0.        , 0.47318807, ..., 0.        , 0.        ,
#          1.9950655 ]], dtype=float32),
#  '219': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.0299966]], dtype=float32),
#  '2355': array([[0.       , 0.       , 2.7394228, ..., 0.       , 1.9517543,
#          0.       ]], dtype=float32),
#  '2054': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.9189613]], dtype=float32),
#  '2308': array([[0.       , 0.6229704, 0.       , ..., 0.       , 2.8941805,
#          0.       ]], dtype=float32),
#  '2230': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.0994527]], dtype=float32),
#  '2095': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2185': array([[0.       , 0.       , 0.       , ..., 0.9542198, 0.       ,
#          3.8937814]], dtype=float32),
#  '2264': array([[0.65239376, 0.        , 0.70932263, ..., 1.1278965 , 2.6206536 ,
#          0.        ]], dtype=float32),
#  '2257': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.657427]],
#        dtype=float32),
#  '2208': array([[0.        , 2.8371627 , 0.        , ..., 0.        , 0.        ,
#          0.28663585]], dtype=float32),
#  '1842': array([[0.        , 0.        , 0.        , ..., 0.49343732, 2.513661  ,
#          0.        ]], dtype=float32),
#  '2260': array([[0.9132366, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2328': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '1995': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.26290748]], dtype=float32),
#  '2102': array([[0.       , 0.       , 0.       , ..., 0.       , 1.8717868,
#          1.9888451]], dtype=float32),
#  '1992': array([[0.78022605, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.23178428]], dtype=float32),
#  '2367': array([[0.88073564, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2245': array([[0.00458837, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.88805825]], dtype=float32),
#  '2013': array([[3.2199492, 0.       , 0.       , ..., 0.       , 5.26118  ,
#          0.       ]], dtype=float32),
#  '2157': array([[0.        , 0.        , 0.37680623, ..., 0.        , 0.        ,
#          0.23777333]], dtype=float32),
#  '2335': array([[4.8480654, 0.       , 0.       , ..., 0.       , 0.       ,
#          3.1315944]], dtype=float32),
#  '2167': array([[0.        , 0.08203724, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2060': array([[0.      , 0.      , 0.      , ..., 0.      , 1.533381, 0.      ]],
#        dtype=float32),
#  '2196': array([[0.60917765, 0.        , 0.        , ..., 0.        , 0.        ,
#          2.4221056 ]], dtype=float32),
#  '2163': array([[0.       , 0.       , 1.6133361, ..., 0.       , 2.5201883,
#          1.2886474]], dtype=float32),
#  '2353': array([[0.2565412 , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.86985415]], dtype=float32),
#  '2029': array([[0.3127838, 2.3516543, 1.3526887, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2143': array([[0.        , 0.86276484, 0.5155439 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2062': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2271': array([[0.        , 0.        , 0.95997244, ..., 0.        , 0.        ,
#          0.8531166 ]], dtype=float32),
#  '2092': array([[0.9922694 , 0.5102593 , 0.19178629, ..., 0.        , 0.        ,
#          0.06779176]], dtype=float32),
#  '214': array([[0.        , 0.7023777 , 0.        , ..., 4.1876087 , 0.96790653,
#          0.        ]], dtype=float32),
#  '2180': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.9681802]], dtype=float32),
#  '2364': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2136': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 1.543591]],
#        dtype=float32),
#  '2285': array([[1.102032 , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.3982825]], dtype=float32),
#  '1942': array([[0.        , 0.        , 0.11547336, ..., 0.        , 0.        ,
#          0.28349054]], dtype=float32),
#  '2023': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2268': array([[0.        , 0.        , 0.        , ..., 0.39084864, 2.7152722 ,
#          0.        ]], dtype=float32),
#  '2036': array([[0.       , 0.       , 0.       , ..., 0.       , 1.2959929,
#          0.       ]], dtype=float32),
#  '2108': array([[0.       , 0.       , 0.       , ..., 0.6551218, 0.       ,
#          0.       ]], dtype=float32),
#  '2004': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.6406038]], dtype=float32),
#  '2246': array([[0.        , 0.        , 3.0014238 , ..., 0.25995028, 0.        ,
#          0.        ]], dtype=float32),
#  '2254': array([[3.1534748, 0.7695022, 0.       , ..., 0.       , 1.0493879,
#          3.0591042]], dtype=float32),
#  '2362': array([[0.       , 3.0548224, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2128': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.886614]],
#        dtype=float32),
#  '2244': array([[0.       , 1.0215259, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2317': array([[0.        , 1.7200329 , 0.        , ..., 0.        , 0.        ,
#          0.94342446]], dtype=float32),
#  '2173': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.36354044]], dtype=float32),
#  '1871': array([[3.4629102, 2.6174107, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2139': array([[0.       , 0.5664168, 0.       , ..., 0.       , 0.       ,
#          1.5320876]], dtype=float32),
#  '2394': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.2546384]], dtype=float32),
#  '565': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.5542674]], dtype=float32),
#  '247': array([[0.        , 0.        , 0.        , ..., 0.        , 0.22720176,
#          1.5496119 ]], dtype=float32),
#  '539': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.5088515]], dtype=float32),
#  '650': array([[2.038039, 2.424789, 0.      , ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '370': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.2171249]], dtype=float32),
#  '401': array([[0.51437473, 2.503571  , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '256': array([[0.9303774, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '549': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '629': array([[0.       , 0.2515909, 0.       , ..., 0.       , 1.9659216,
#          3.5662663]], dtype=float32),
#  '654': array([[0.        , 0.        , 0.        , ..., 0.41768473, 0.        ,
#          0.36719835]], dtype=float32),
#  '2474': array([[1.0679507, 1.6819069, 0.       , ..., 0.       , 1.0582768,
#          0.       ]], dtype=float32),
#  '241': array([[0.       , 2.5392392, 0.       , ..., 3.5026212, 0.       ,
#          0.       ]], dtype=float32),
#  '424': array([[0.        , 0.        , 0.        , ..., 0.        , 0.03261155,
#          0.25056863]], dtype=float32),
#  '490': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '369': array([[0.750888 , 0.6364955, 0.       , ..., 0.       , 0.       ,
#          1.8480608]], dtype=float32),
#  '597': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '500': array([[0.        , 0.14281133, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '398': array([[1.3981154 , 0.53743637, 1.3598906 , ..., 0.        , 0.        ,
#          1.6531243 ]], dtype=float32),
#  '311': array([[0.09102094, 0.8002584 , 2.1982543 , ..., 0.        , 0.        ,
#          2.0838575 ]], dtype=float32),
#  '277': array([[4.6630974 , 0.        , 0.22112733, ..., 0.        , 0.        ,
#          2.935657  ]], dtype=float32),
#  '2490': array([[1.7841326, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.7563229]], dtype=float32),
#  '599': array([[0.       , 0.       , 0.       , ..., 0.       , 1.0201817,
#          0.8071687]], dtype=float32),
#  '2381': array([[0.       , 1.6605682, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '537': array([[0.       , 0.       , 0.7137549, ..., 0.       , 0.       ,
#          3.9288104]], dtype=float32),
#  '2464': array([[0.       , 3.3000598, 0.       , ..., 0.4824444, 1.4920874,
#          0.       ]], dtype=float32),
#  '300': array([[1.1724316, 0.       , 0.       , ..., 0.1447418, 0.       ,
#          0.       ]], dtype=float32),
#  '520': array([[0.       , 2.9936018, 2.6968708, ..., 0.       , 2.6491053,
#          0.       ]], dtype=float32),
#  '341': array([[0.842027  , 4.664429  , 0.        , ..., 0.        , 0.46792412,
#          0.        ]], dtype=float32),
#  '618': array([[0.       , 3.1522002, 0.       , ..., 0.       , 0.       ,
#          1.4832736]], dtype=float32),
#  '357': array([[0.       , 0.       , 2.8896866, ..., 0.       , 2.6314476,
#          2.0945146]], dtype=float32),
#  '2471': array([[0.       , 1.7764087, 0.       , ..., 0.       , 0.       ,
#          1.5235171]], dtype=float32),
#  '2448': array([[0.14442992, 0.        , 0.        , ..., 0.        , 0.        ,
#          1.7002988 ]], dtype=float32),
#  '374': array([[0.91583073, 0.        , 0.        , ..., 2.1107051 , 4.091525  ,
#          0.        ]], dtype=float32),
#  '301': array([[2.062962 , 0.       , 2.4090376, ..., 0.       , 0.       ,
#          1.3284335]], dtype=float32),
#  '326': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.6621597]], dtype=float32),
#  '463': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '505': array([[0.70603186, 0.        , 0.83934927, ..., 0.        , 1.2291741 ,
#          0.5519916 ]], dtype=float32),
#  '2497': array([[0.       , 0.       , 0.       , ..., 0.       , 2.2285602,
#          2.0959747]], dtype=float32),
#  '2450': array([[0.       , 0.       , 0.482446 , ..., 0.       , 0.       ,
#          3.1221683]], dtype=float32),
#  '361': array([[0.5948701, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '67': array([[0.       , 0.4489226, 0.       , ..., 0.       , 0.       ,
#          0.9036834]], dtype=float32),
#  '255': array([[0.9345621, 0.       , 2.417663 , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2400': array([[0.691165 , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.5064974]], dtype=float32),
#  '329': array([[0.       , 0.       , 0.5937862, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2492': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.09830523]], dtype=float32),
#  '682': array([[0.04090744, 3.15724   , 0.        , ..., 2.185466  , 1.3289275 ,
#          0.        ]], dtype=float32),
#  '600': array([[0.856464  , 0.40347603, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2375': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.4087095]], dtype=float32),
#  '568': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '281': array([[0.       , 0.       , 0.       , ..., 0.       , 1.636075 ,
#          2.3035362]], dtype=float32),
#  '278': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.12444454]], dtype=float32),
#  '34': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '621': array([[0.       , 0.       , 1.0944486, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '489': array([[0.       , 1.9700955, 0.       , ..., 0.       , 0.       ,
#          0.2932815]], dtype=float32),
#  '2403': array([[1.0382109 , 0.        , 0.18880129, ..., 0.        , 0.        ,
#          0.0510152 ]], dtype=float32),
#  '590': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.6325078]], dtype=float32),
#  '3': array([[0.       , 0.       , 0.       , ..., 0.       , 0.8644194,
#          1.5810659]], dtype=float32),
#  '272': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2417': array([[0.       , 0.       , 0.       , ..., 0.       , 1.2585397,
#          1.7109427]], dtype=float32),
#  '274': array([[1.1684155, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '561': array([[0.        , 0.        , 0.47175258, ..., 0.        , 0.        ,
#          1.1952116 ]], dtype=float32),
#  '694': array([[0.6403126, 0.       , 1.6590364, ..., 0.       , 1.8896117,
#          1.1644995]], dtype=float32),
#  '366': array([[ 0.        ,  0.8344501 , 10.071384  , ...,  0.        ,
#           0.05934149,  0.        ]], dtype=float32),
#  '643': array([[0.        , 1.255133  , 0.        , ..., 0.        , 0.37115955,
#          0.        ]], dtype=float32),
#  '286': array([[0.       , 0.       , 4.665365 , ..., 0.       , 0.       ,
#          1.7632806]], dtype=float32),
#  '345': array([[0.        , 0.        , 0.5548027 , ..., 0.        , 0.        ,
#          0.43688822]], dtype=float32),
#  '240': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 3.489597]],
#        dtype=float32),
#  '428': array([[2.0014863 , 0.19632035, 2.0948162 , ..., 0.        , 0.        ,
#          1.5026944 ]], dtype=float32),
#  '38': array([[0.       , 1.3824378, 0.       , ..., 0.       , 1.2040724,
#          0.       ]], dtype=float32),
#  '387': array([[1.3799945, 2.5480933, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '52': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.75238585]], dtype=float32),
#  '445': array([[0.529389  , 0.        , 0.76338226, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '55': array([[0.       , 0.7358537, 0.1367954, ..., 0.       , 1.3505511,
#          0.       ]], dtype=float32),
#  '431': array([[0.42146152, 1.6539886 , 2.078135  , ..., 0.11477971, 1.1433882 ,
#          0.        ]], dtype=float32),
#  '2427': array([[0.        , 0.19565022, 0.        , ..., 0.        , 2.4851725 ,
#          0.        ]], dtype=float32),
#  '508': array([[0.       , 3.6386297, 2.1228333, ..., 2.6218321, 0.       ,
#          0.4260093]], dtype=float32),
#  '393': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '453': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.2820549]], dtype=float32),
#  '2412': array([[0.      , 1.240709, 0.      , ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '417': array([[0.43333203, 0.        , 1.2733861 , ..., 0.42275238, 0.6761007 ,
#          0.5075346 ]], dtype=float32),
#  '2399': array([[0.       , 0.       , 0.       , ..., 0.       , 1.8526504,
#          2.4552443]], dtype=float32),
#  '344': array([[0.       , 0.       , 0.       , ..., 0.       , 1.7127469,
#          2.5707998]], dtype=float32),
#  '653': array([[0.       , 0.6339369, 0.       , ..., 0.       , 0.       ,
#          2.0621536]], dtype=float32),
#  '627': array([[1.8443569 , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.04900897]], dtype=float32),
#  '435': array([[0.       , 0.       , 0.       , ..., 0.       , 1.8979821,
#          0.       ]], dtype=float32),
#  '491': array([[0.29108077, 0.        , 0.        , ..., 0.        , 0.        ,
#          2.7535548 ]], dtype=float32),
#  '2478': array([[0.521122 , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.3297284]], dtype=float32),
#  '425': array([[1.324043 , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.6192381]], dtype=float32),
#  '696': array([[0.       , 3.3425481, 0.       , ..., 0.       , 4.316731 ,
#          0.       ]], dtype=float32),
#  '27': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.8728351]], dtype=float32),
#  '631': array([[0.36019474, 0.        , 1.1099913 , ..., 0.        , 0.        ,
#          1.9746885 ]], dtype=float32),
#  '2398': array([[0.       , 0.       , 0.       , ..., 0.       , 1.0545678,
#          2.3268561]], dtype=float32),
#  '569': array([[0.8446218, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.5276708]], dtype=float32),
#  '608': array([[0.        , 4.624391  , 0.13395116, ..., 0.        , 3.0645397 ,
#          0.55426276]], dtype=float32),
#  '368': array([[2.3425364 , 0.91170335, 0.62364596, ..., 0.        , 2.4995687 ,
#          0.        ]], dtype=float32),
#  '63': array([[0.       , 0.       , 0.       , ..., 0.       , 1.8063164,
#          1.0293801]], dtype=float32),
#  '372': array([[0.        , 0.        , 0.54697245, ..., 2.5524044 , 3.2491608 ,
#          0.        ]], dtype=float32),
#  '620': array([[1.5939784, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.7234766]], dtype=float32),
#  '502': array([[0.        , 0.        , 0.02114898, ..., 0.        , 0.        ,
#          1.467536  ]], dtype=float32),
#  '488': array([[0.       , 0.       , 0.       , ..., 0.       , 0.3744529,
#          1.7084904]], dtype=float32),
#  '2408': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.13414484]], dtype=float32),
#  '335': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.48167098]], dtype=float32),
#  '304': array([[0.       , 1.2052398, 0.       , ..., 0.       , 0.       ,
#          1.5904194]], dtype=float32),
#  '641': array([[1.2115326 , 0.        , 0.83208585, ..., 0.        , 2.097389  ,
#          0.6247687 ]], dtype=float32),
#  '249': array([[0.       , 0.9073224, 1.4324712, ..., 0.       , 0.       ,
#          0.2593186]], dtype=float32),
#  '338': array([[0.07805687, 1.8338182 , 1.1689498 , ..., 3.7521358 , 2.5550034 ,
#          0.        ]], dtype=float32),
#  '43': array([[0.       , 2.8529353, 0.       , ..., 0.       , 0.       ,
#          1.983969 ]], dtype=float32),
#  '583': array([[1.835352  , 0.42908093, 0.13219917, ..., 0.        , 2.1912904 ,
#          0.        ]], dtype=float32),
#  '351': array([[0.       , 0.       , 0.       , ..., 0.       , 2.2863193,
#          0.       ]], dtype=float32),
#  '513': array([[0.       , 0.       , 1.7252153, ..., 0.       , 1.3922622,
#          0.4222182]], dtype=float32),
#  '2422': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.7312968]], dtype=float32),
#  '323': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2432': array([[1.4272432 , 0.        , 4.338968  , ..., 0.        , 0.41567022,
#          2.8618    ]], dtype=float32),
#  '388': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.9686322]], dtype=float32),
#  '389': array([[2.7051258 , 4.7203307 , 3.008852  , ..., 0.        , 0.80164397,
#          1.6659558 ]], dtype=float32),
#  '68': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '379': array([[1.9128243, 0.       , 2.0918422, ..., 0.       , 0.3342728,
#          1.8021998]], dtype=float32),
#  '493': array([[0.       , 0.       , 0.       , ..., 0.       , 5.4317575,
#          0.       ]], dtype=float32),
#  '671': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.0560298]], dtype=float32),
#  '649': array([[0.       , 1.9638724, 0.       , ..., 0.       , 0.       ,
#          1.0382247]], dtype=float32),
#  '426': array([[0.6020395, 0.       , 0.       , ..., 0.       , 0.       ,
#          2.9396565]], dtype=float32),
#  '371': array([[0.9471902, 0.       , 3.4081292, ..., 0.       , 0.       ,
#          2.2453604]], dtype=float32),
#  '556': array([[0.        , 0.14256468, 0.18880525, ..., 0.        , 0.92721164,
#          0.        ]], dtype=float32),
#  '280': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.21821737]], dtype=float32),
#  '655': array([[ 3.4480348,  0.       , 10.729865 , ...,  0.       ,  0.       ,
#           0.       ]], dtype=float32),
#  '588': array([[2.1014214 , 0.        , 0.14765024, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '507': array([[1.9946208 , 0.43969676, 0.        , ..., 0.        , 0.7285948 ,
#          0.        ]], dtype=float32),
#  '327': array([[0.       , 2.0803807, 0.       , ..., 0.       , 1.9874384,
#          0.       ]], dtype=float32),
#  '562': array([[1.6361666, 2.5512416, 0.       , ..., 0.       , 4.605769 ,
#          0.       ]], dtype=float32),
#  '273': array([[1.1997483, 0.       , 1.4937222, ..., 0.       , 0.       ,
#          0.997322 ]], dtype=float32),
#  '54': array([[1.6318121, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2447': array([[0.74913245, 0.        , 0.        , ..., 0.50221026, 0.        ,
#          0.        ]], dtype=float32),
#  '572': array([[0.        , 0.64517665, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '60': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.2944403]], dtype=float32),
#  '652': array([[2.2421415 , 0.        , 0.        , ..., 0.        , 1.03511   ,
#          0.02345783]], dtype=float32),
#  '673': array([[0.3275348 , 0.41106382, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2486': array([[0.       , 0.       , 0.       , ..., 0.       , 0.7930685,
#          0.       ]], dtype=float32),
#  '2424': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.253395]],
#        dtype=float32),
#  '382': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.969803]],
#        dtype=float32),
#  '2390': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.4562154]], dtype=float32),
#  '447': array([[0.       , 3.5411575, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '290': array([[0.       , 0.       , 0.       , ..., 0.       , 0.6782323,
#          0.       ]], dtype=float32),
#  '540': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.624021]],
#        dtype=float32),
#  '325': array([[0.92241067, 0.5636382 , 0.        , ..., 0.        , 2.7064455 ,
#          0.        ]], dtype=float32),
#  '506': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '30': array([[0.11466897, 1.0503684 , 0.        , ..., 0.        , 4.383535  ,
#          0.        ]], dtype=float32),
#  '2404': array([[2.0163908, 0.       , 0.       , ..., 0.       , 0.       ,
#          2.6635375]], dtype=float32),
#  '270': array([[0.        , 0.        , 0.79622924, ..., 1.680352  , 0.        ,
#          0.        ]], dtype=float32),
#  '421': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.9375482]], dtype=float32),
#  '444': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.7398422]], dtype=float32),
#  '265': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2453': array([[0.        , 4.5069737 , 1.7393873 , ..., 0.        , 0.67483944,
#          0.        ]], dtype=float32),
#  '376': array([[0.       , 4.9486065, 0.       , ..., 0.       , 3.3906484,
#          0.       ]], dtype=float32),
#  '407': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '263': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '414': array([[4.409031 , 3.9524152, 0.       , ..., 0.       , 1.3242018,
#          0.       ]], dtype=float32),
#  '691': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '367': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.3107812]], dtype=float32),
#  '253': array([[0.        , 0.9426048 , 0.56611925, ..., 1.6393611 , 0.66887605,
#          0.        ]], dtype=float32),
#  '433': array([[0.       , 0.       , 0.       , ..., 0.       , 2.2477524,
#          0.       ]], dtype=float32),
#  '658': array([[0.        , 0.        , 1.5624766 , ..., 0.19181082, 1.4311442 ,
#          1.3456883 ]], dtype=float32),
#  '558': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '29': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '364': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.2875562]], dtype=float32),
#  '480': array([[0.988794 , 3.628171 , 0.       , ..., 0.       , 3.7303808,
#          0.       ]], dtype=float32),
#  '614': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.26065758]], dtype=float32),
#  '674': array([[0.        , 0.        , 0.04725671, ..., 0.        , 0.        ,
#          1.203264  ]], dtype=float32),
#  '397': array([[0.24663407, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.33367974]], dtype=float32),
#  '25': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '252': array([[0.        , 0.        , 0.        , ..., 0.        , 0.40687913,
#          0.        ]], dtype=float32),
#  '377': array([[0.       , 0.       , 0.       , ..., 0.7025887, 0.       ,
#          0.       ]], dtype=float32),
#  '533': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '360': array([[1.7330807 , 0.97393715, 0.9981914 , ..., 0.        , 2.3191266 ,
#          0.        ]], dtype=float32),
#  '560': array([[0.27141994, 2.9010522 , 8.852038  , ..., 7.071724  , 0.        ,
#          0.        ]], dtype=float32),
#  '356': array([[0.        , 0.        , 1.17827   , ..., 0.        , 0.        ,
#          0.07907897]], dtype=float32),
#  '498': array([[1.6433425, 0.       , 2.4645271, ..., 0.       , 0.       ,
#          1.4893781]], dtype=float32),
#  '2500': array([[1.3984036, 2.4682224, 0.       , ..., 0.       , 0.       ,
#          1.6613386]], dtype=float32),
#  '526': array([[0.       , 0.       , 0.       , ..., 0.       , 0.9152435,
#          1.9660454]], dtype=float32),
#  '647': array([[0.       , 2.9556818, 0.       , ..., 0.       , 0.       ,
#          3.1147616]], dtype=float32),
#  '2438': array([[0.       , 0.3445249, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '399': array([[0.        , 0.        , 0.49281377, ..., 1.1726651 , 0.819029  ,
#          0.        ]], dtype=float32),
#  '406': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.69093096]], dtype=float32),
#  '623': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '567': array([[0.        , 0.79216427, 0.29078817, ..., 0.        , 4.477483  ,
#          0.31019425]], dtype=float32),
#  '644': array([[0.00845456, 0.8060131 , 0.        , ..., 0.        , 0.69410765,
#          3.658502  ]], dtype=float32),
#  '579': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.3412824]], dtype=float32),
#  '394': array([[0.        , 1.0939697 , 0.        , ..., 0.        , 0.        ,
#          0.22429144]], dtype=float32),
#  '416': array([[0.        , 0.4733554 , 0.7724509 , ..., 0.        , 4.8289366 ,
#          0.34422123]], dtype=float32),
#  '446': array([[2.7749104 , 0.        , 0.96311545, ..., 0.        , 1.0117805 ,
#          1.0810807 ]], dtype=float32),
#  '527': array([[0.26263213, 2.0497782 , 0.        , ..., 0.12017396, 0.8265396 ,
#          0.        ]], dtype=float32),
#  '2423': array([[0.38493946, 0.6196541 , 0.        , ..., 0.        , 1.1385956 ,
#          0.        ]], dtype=float32),
#  '672': array([[0.       , 1.3909327, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '477': array([[0.      , 0.      , 2.557812, ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '553': array([[0.       , 0.       , 0.       , ..., 0.       , 2.8289757,
#          1.5338401]], dtype=float32),
#  '571': array([[0.       , 0.       , 0.5246434, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2441': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.52980125]], dtype=float32),
#  '381': array([[0.4079756, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '418': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '261': array([[0.       , 0.       , 5.196758 , ..., 2.5488675, 2.8098748,
#          0.       ]], dtype=float32),
#  '499': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.19160414]], dtype=float32),
#  '2389': array([[0.7721516, 2.2549262, 0.       , ..., 0.       , 0.       ,
#          1.9823334]], dtype=float32),
#  '315': array([[0.92896396, 0.        , 0.3574287 , ..., 2.5335066 , 0.        ,
#          0.        ]], dtype=float32),
#  '26': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '475': array([[0.       , 0.       , 0.       , ..., 0.       , 2.0472512,
#          0.       ]], dtype=float32),
#  '541': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '42': array([[0.01430738, 0.24844995, 0.        , ..., 0.        , 0.        ,
#          0.9224816 ]], dtype=float32),
#  '596': array([[2.5876064, 2.8868744, 0.       , ..., 0.       , 1.5435667,
#          0.       ]], dtype=float32),
#  '454': array([[0.       , 0.       , 1.7577053, ..., 0.       , 0.       ,
#          1.8276033]], dtype=float32),
#  '534': array([[0.       , 0.       , 1.2761877, ..., 0.7310688, 0.       ,
#          0.       ]], dtype=float32),
#  '2434': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.5912611]], dtype=float32),
#  '458': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.6248397]], dtype=float32),
#  '2411': array([[0.       , 0.       , 0.6912029, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '309': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '471': array([[0.       , 2.3887935, 0.       , ..., 0.6887906, 0.       ,
#          2.5887573]], dtype=float32),
#  '545': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 5.237959]],
#        dtype=float32),
#  '2377': array([[0.       , 0.       , 2.7021408, ..., 0.       , 0.       ,
#          0.3807853]], dtype=float32),
#  '639': array([[1.4900075 , 2.5905292 , 0.        , ..., 0.21324101, 0.        ,
#          0.        ]], dtype=float32),
#  '440': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.1874049]], dtype=float32),
#  '347': array([[1.3604159, 0.       , 2.2186708, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '254': array([[0.       , 0.       , 0.       , ..., 0.       , 1.1904136,
#          2.1787233]], dtype=float32),
#  '686': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.349101]],
#        dtype=float32),
#  '648': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '419': array([[0.       , 0.       , 2.9016385, ..., 0.       , 0.8632976,
#          0.       ]], dtype=float32),
#  '474': array([[0.       , 0.       , 1.190687 , ..., 0.       , 0.       ,
#          0.9660967]], dtype=float32),
#  '2425': array([[0.        , 0.935078  , 0.        , ..., 0.        , 0.99956197,
#          0.08498603]], dtype=float32),
#  '262': array([[0.39578852, 0.        , 0.        , ..., 0.        , 0.        ,
#          1.7372026 ]], dtype=float32),
#  '478': array([[0.        , 2.7622702 , 3.5617476 , ..., 0.66380733, 3.3283358 ,
#          0.        ]], dtype=float32),
#  '2460': array([[0.        , 0.        , 0.42695594, ..., 0.09662059, 0.        ,
#          2.1775694 ]], dtype=float32),
#  '328': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '587': array([[0.       , 0.       , 0.       , ..., 0.       , 1.0134227,
#          4.0837154]], dtype=float32),
#  '49': array([[0.      , 6.828606, 6.936959, ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '601': array([[0.        , 5.404205  , 0.        , ..., 0.        , 0.62335664,
#          0.        ]], dtype=float32),
#  '611': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2379': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.7954941]], dtype=float32),
#  '2461': array([[0.       , 0.       , 0.       , ..., 0.       , 1.7685986,
#          0.       ]], dtype=float32),
#  '511': array([[0.4212782 , 0.2908602 , 0.        , ..., 0.        , 0.82702625,
#          3.331791  ]], dtype=float32),
#  '41': array([[0.04974753, 0.        , 0.        , ..., 0.        , 0.        ,
#          3.9532506 ]], dtype=float32),
#  '651': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.4563842]], dtype=float32),
#  '630': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2498': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.2044053]], dtype=float32),
#  '246': array([[0.6011349 , 0.        , 0.08013773, ..., 0.        , 0.        ,
#          5.3747554 ]], dtype=float32),
#  '473': array([[0.       , 0.       , 0.6858439, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '346': array([[ 0.      ,  0.      ,  0.      , ...,  0.      , 13.759097,
#           0.      ]], dtype=float32),
#  '2467': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.4190056]], dtype=float32),
#  '2452': array([[2.008883 , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.3564088]], dtype=float32),
#  '524': array([[0.        , 0.        , 0.        , ..., 0.53595227, 0.        ,
#          0.        ]], dtype=float32),
#  '441': array([[1.1693504, 1.9871945, 0.       , ..., 0.       , 0.       ,
#          1.7831743]], dtype=float32),
#  '245': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '423': array([[3.397295 , 0.       , 0.       , ..., 0.       , 0.7644798,
#          2.9834142]], dtype=float32),
#  '2472': array([[0.        , 0.63505113, 0.        , ..., 0.        , 0.        ,
#          0.06868452]], dtype=float32),
#  '2488': array([[1.1326704 , 0.        , 0.        , ..., 0.        , 2.4141982 ,
#          0.94259584]], dtype=float32),
#  '634': array([[0.01972324, 0.        , 4.37291   , ..., 0.        , 0.        ,
#          0.11336583]], dtype=float32),
#  '2473': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.3133004]], dtype=float32),
#  '456': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 3.111157]],
#        dtype=float32),
#  '532': array([[2.1038241, 0.       , 0.       , ..., 0.       , 1.038671 ,
#          0.974303 ]], dtype=float32),
#  '695': array([[0.        , 0.        , 0.        , ..., 0.        , 0.48382378,
#          1.841238  ]], dtype=float32),
#  '628': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.11993176]], dtype=float32),
#  '295': array([[0.04697686, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.22033745]], dtype=float32),
#  '2489': array([[0.       , 0.       , 1.7612222, ..., 0.       , 0.       ,
#          1.3302071]], dtype=float32),
#  '514': array([[0.        , 0.        , 3.1979394 , ..., 0.        , 1.8439505 ,
#          0.37957305]], dtype=float32),
#  '576': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '582': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '586': array([[0.        , 2.438439  , 2.0511417 , ..., 0.72207594, 0.        ,
#          0.        ]], dtype=float32),
#  '679': array([[3.9636497, 2.132563 , 0.6340744, ..., 0.       , 2.067523 ,
#          0.       ]], dtype=float32),
#  '548': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.4057682]], dtype=float32),
#  '2414': array([[0.89503765, 0.        , 0.        , ..., 0.        , 0.        ,
#          2.6451476 ]], dtype=float32),
#  '451': array([[1.1829588, 2.0806968, 0.       , ..., 0.       , 3.776425 ,
#          2.041393 ]], dtype=float32),
#  '632': array([[0.       , 3.7567728, 1.0491377, ..., 0.       , 1.7627115,
#          0.       ]], dtype=float32),
#  '547': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.0314045]], dtype=float32),
#  '65': array([[1.7890387, 1.0551434, 0.       , ..., 1.2579013, 2.8132498,
#          0.       ]], dtype=float32),
#  '483': array([[0.       , 3.4568517, 0.       , ..., 0.       , 0.       ,
#          3.5182831]], dtype=float32),
#  '312': array([[0.       , 1.2090706, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '626': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '589': array([[1.7799351, 0.       , 2.5206964, ..., 0.9708339, 0.       ,
#          0.3747015]], dtype=float32),
#  '452': array([[0.       , 0.       , 2.316559 , ..., 0.       , 0.       ,
#          2.3541663]], dtype=float32),
# ...
#          0.       ]], dtype=float32),
#  '859': array([[0.       , 0.       , 0.       , ..., 0.       , 0.3063917,
#          0.       ]], dtype=float32),
#  '895': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.341063]],
#        dtype=float32),
#  '699': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          4.0091643]], dtype=float32),
#  '747': array([[0.       , 3.8917427, 0.       , ..., 0.       , 2.973087 ,
#          0.       ]], dtype=float32),
#  '728': array([[1.2067546 , 1.6460303 , 2.6272187 , ..., 0.5217302 , 0.        ,
#          0.12329596]], dtype=float32),
#  '817': array([[0.       , 0.       , 2.2404714, ..., 0.       , 0.       ,
#          4.5902596]], dtype=float32),
#  '927': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          4.8227534]], dtype=float32),
#  '776': array([[2.357256 , 0.       , 0.       , ..., 0.       , 0.5959259,
#          1.6927278]], dtype=float32),
#  '734': array([[0.9931438 , 1.8388253 , 0.9600246 , ..., 0.        , 0.74419856,
#          0.36225727]], dtype=float32),
#  '811': array([[0.        , 0.26804036, 0.        , ..., 0.        , 0.        ,
#          2.9267893 ]], dtype=float32),
#  '875': array([[2.962759 , 0.       , 0.       , ..., 0.       , 1.0132694,
#          1.9023554]], dtype=float32),
#  '877': array([[3.3647618 , 0.        , 0.        , ..., 0.23777881, 0.09780982,
#          1.8793571 ]], dtype=float32),
#  '778': array([[0.       , 7.51531  , 0.8305032, ..., 0.       , 0.       ,
#          1.0885231]], dtype=float32),
#  '863': array([[2.428981 , 0.       , 0.       , ..., 0.       , 1.3595079,
#          1.9691188]], dtype=float32),
#  '918': array([[0.64392126, 0.16720822, 0.        , ..., 0.        , 3.3513486 ,
#          0.        ]], dtype=float32),
#  '831': array([[0.        , 1.1486636 , 0.        , ..., 0.        , 0.96927637,
#          3.9473722 ]], dtype=float32),
#  '858': array([[0.        , 0.94605255, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '878': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '903': array([[0.        , 0.        , 1.6213199 , ..., 0.75508475, 0.        ,
#          1.5422974 ]], dtype=float32),
#  '751': array([[0.6982577, 0.       , 0.       , ..., 0.       , 0.       ,
#          2.9258783]], dtype=float32),
#  '84': array([[0.8980573, 0.       , 2.393296 , ..., 1.3881811, 0.       ,
#          1.1292061]], dtype=float32),
#  '924': array([[0.        , 0.        , 0.38493603, ..., 0.        , 0.        ,
#          4.074189  ]], dtype=float32),
#  '900': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.19745591]], dtype=float32),
#  '939': array([[0.       , 0.       , 2.1271687, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '81': array([[0.       , 0.       , 2.5107818, ..., 1.1588709, 0.       ,
#          1.0101676]], dtype=float32),
#  '706': array([[0.       , 2.6507428, 0.       , ..., 0.       , 4.2106524,
#          0.       ]], dtype=float32),
#  '737': array([[0.       , 0.       , 0.       , ..., 0.       , 1.7893939,
#          0.       ]], dtype=float32),
#  '893': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '911': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '710': array([[0.       , 1.8189609, 0.       , ..., 0.       , 0.       ,
#          0.7517659]], dtype=float32),
#  '937': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.9942792]], dtype=float32),
#  '705': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '85': array([[2.106132  , 0.        , 1.4615232 , ..., 0.        , 0.        ,
#          0.42483753]], dtype=float32),
#  '83': array([[0.48051748, 0.        , 0.09259209, ..., 0.        , 0.        ,
#          0.33678585]], dtype=float32),
#  '741': array([[0.       , 0.       , 1.6832725, ..., 0.       , 1.595628 ,
#          4.9924455]], dtype=float32),
#  '964': array([[0.8610022, 2.7805932, 0.       , ..., 0.       , 1.7269824,
#          3.0807092]], dtype=float32),
#  '785': array([[0.5934984 , 0.        , 3.5772662 , ..., 0.        , 0.        ,
#          0.87538177]], dtype=float32),
#  '745': array([[0.       , 0.       , 0.       , ..., 0.       , 2.4743035,
#          3.555967 ]], dtype=float32),
#  '761': array([[0.       , 0.       , 0.       , ..., 0.       , 0.7113437,
#          1.6958365]], dtype=float32),
#  '750': array([[0.       , 0.4335067, 0.       , ..., 0.       , 2.839539 ,
#          0.       ]], dtype=float32),
#  '78': array([[2.8249798 , 0.55054784, 0.        , ..., 0.        , 1.8713162 ,
#          0.43165258]], dtype=float32),
#  '894': array([[0.        , 0.        , 0.85211986, ..., 0.        , 0.        ,
#          0.83534086]], dtype=float32),
#  '716': array([[0.       , 2.3575013, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '830': array([[1.2125876 , 3.088856  , 0.38415635, ..., 0.        , 2.8339765 ,
#          0.        ]], dtype=float32),
#  '795': array([[0.      , 0.      , 4.104968, ..., 1.607877, 0.      , 0.      ]],
#        dtype=float32),
#  '780': array([[1.5073116, 0.       , 2.7029538, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '906': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.578228]],
#        dtype=float32),
#  '887': array([[0.       , 0.       , 0.       , ..., 0.       , 2.7760055,
#          0.098297 ]], dtype=float32),
#  '819': array([[0.       , 2.6455138, 0.       , ..., 0.       , 0.       ,
#          2.4727147]], dtype=float32),
#  '944': array([[0.       , 6.652822 , 1.4203466, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '809': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '96': array([[0.        , 0.40695184, 1.9794569 , ..., 0.        , 0.36168194,
#          2.0443902 ]], dtype=float32),
#  '840': array([[0.       , 2.7089014, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '796': array([[0.        , 0.        , 0.        , ..., 0.        , 0.40521646,
#          4.587971  ]], dtype=float32),
#  '797': array([[0.       , 0.923545 , 1.0964583, ..., 2.8962815, 0.       ,
#          0.       ]], dtype=float32),
#  '910': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.3326864]], dtype=float32),
#  '883': array([[1.3409991 , 0.36210823, 0.        , ..., 0.        , 0.5908338 ,
#          2.2550955 ]], dtype=float32),
#  '725': array([[1.9373766, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '976': array([[0.       , 0.       , 0.       , ..., 0.       , 2.7266712,
#          0.       ]], dtype=float32),
#  '841': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          4.7980905]], dtype=float32),
#  '90': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.2314031]], dtype=float32),
#  '73': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '930': array([[0.       , 4.187122 , 0.       , ..., 0.       , 0.       ,
#          0.7341465]], dtype=float32),
#  '738': array([[1.7643942, 1.7189896, 0.       , ..., 0.       , 0.       ,
#          2.1639652]], dtype=float32),
#  '932': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '847': array([[0.       , 3.8490512, 1.596756 , ..., 0.       , 0.1427601,
#          0.       ]], dtype=float32),
#  '820': array([[0.        , 0.21958378, 0.17900077, ..., 0.        , 0.        ,
#          0.06094456]], dtype=float32),
#  '87': array([[0.       , 2.1854475, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '729': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 1.845509]],
#        dtype=float32),
#  '92': array([[2.7090464, 1.4267769, 0.       , ..., 0.       , 0.5318674,
#          0.       ]], dtype=float32),
#  '844': array([[2.4492908, 0.       , 0.       , ..., 0.       , 2.6817596,
#          0.2600165]], dtype=float32),
#  '899': array([[0.        , 0.00963506, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '74': array([[1.728541, 0.      , 3.230979, ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '915': array([[4.1651707, 3.9711506, 2.7483954, ..., 6.8537183, 0.       ,
#          0.       ]], dtype=float32),
#  '898': array([[0.        , 0.        , 0.61856246, ..., 0.        , 0.9667444 ,
#          0.        ]], dtype=float32),
#  '779': array([[0.       , 1.6319525, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '777': array([[0.       , 5.238126 , 5.5530834, ..., 2.3192558, 3.6607647,
#          0.       ]], dtype=float32),
#  '75': array([[0.        , 0.54316556, 2.6171117 , ..., 0.5239928 , 0.        ,
#          2.4297884 ]], dtype=float32),
#  '986': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '958': array([[0.        , 0.08647531, 0.4539393 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '988': array([[1.3571031, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '881': array([[1.266367 , 1.8926182, 1.137665 , ..., 0.       , 0.       ,
#          1.7209132]], dtype=float32),
#  '968': array([[0.        , 3.3311543 , 0.        , ..., 0.        , 0.04031512,
#          0.        ]], dtype=float32),
#  '703': array([[0.       , 0.       , 0.765627 , ..., 0.       , 1.2501624,
#          2.1801105]], dtype=float32),
#  '938': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '763': array([[1.1483256, 0.8270817, 0.       , ..., 0.       , 0.       ,
#          0.5947533]], dtype=float32),
#  '793': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '762': array([[0.76004255, 0.6889787 , 0.        , ..., 0.        , 0.        ,
#          0.97157216]], dtype=float32),
#  '869': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.6158733]], dtype=float32),
#  '872': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '928': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.9952959]], dtype=float32),
#  '810': array([[0.      , 0.      , 0.      , ..., 0.      , 2.756917, 0.      ]],
#        dtype=float32),
#  '871': array([[0.18875194, 1.918792  , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '949': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.17680085]], dtype=float32),
#  '948': array([[0.        , 0.        , 0.05573583, ..., 0.        , 1.7564578 ,
#          0.        ]], dtype=float32),
#  '71': array([[0.       , 0.       , 0.       , ..., 0.8557297, 0.       ,
#          4.50204  ]], dtype=float32),
#  '868': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.9779282]], dtype=float32),
#  '921': array([[0.        , 0.        , 0.        , ..., 0.        , 0.58356935,
#          0.        ]], dtype=float32),
#  '882': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.90758747]], dtype=float32),
#  '93': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '753': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.34489897]], dtype=float32),
#  '864': array([[0.       , 0.       , 0.       , ..., 0.       , 1.717361 ,
#          1.5087516]], dtype=float32),
#  '835': array([[0.        , 0.        , 0.31462836, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '807': array([[0.       , 0.       , 0.       , ..., 0.       , 1.6077847,
#          0.       ]], dtype=float32),
#  '845': array([[0.       , 3.4802191, 0.       , ..., 0.       , 0.       ,
#          2.1571524]], dtype=float32),
#  '709': array([[0.       , 2.4092464, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '722': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '947': array([[0.        , 0.85315454, 0.20672351, ..., 0.93605006, 0.        ,
#          0.        ]], dtype=float32),
#  '82': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '730': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 5.510077]],
#        dtype=float32),
#  '698': array([[0.       , 0.       , 0.       , ..., 0.       , 1.2553991,
#          1.3542349]], dtype=float32),
#  '833': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '718': array([[0.        , 1.9557177 , 0.        , ..., 0.        , 2.2309601 ,
#          0.27424833]], dtype=float32),
#  '940': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '979': array([[0.       , 1.1205871, 1.2914443, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '711': array([[0.        , 0.        , 1.0832193 , ..., 0.00376159, 2.918732  ,
#          0.        ]], dtype=float32),
#  '834': array([[0.        , 0.70510745, 0.        , ..., 0.        , 0.2170063 ,
#          0.46435508]], dtype=float32),
#  '908': array([[3.2469497, 2.4376576, 0.       , ..., 0.       , 0.       ,
#          3.8084383]], dtype=float32),
#  '981': array([[0.       , 0.       , 0.       , ..., 0.       , 2.4871914,
#          2.007363 ]], dtype=float32),
#  '712': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '842': array([[0.       , 0.       , 1.0709531, ..., 0.       , 1.3855307,
#          0.       ]], dtype=float32),
#  '766': array([[0.62646425, 0.56851345, 0.        , ..., 0.        , 0.        ,
#          0.97081935]], dtype=float32),
#  '8': array([[1.9226419, 1.0669581, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '755': array([[0.       , 0.       , 0.       , ..., 0.       , 2.0447702,
#          1.3158896]], dtype=float32),
#  '985': array([[0.        , 6.6939416 , 0.75078857, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '946': array([[0.43777192, 1.5940604 , 0.        , ..., 0.        , 1.6689103 ,
#          2.8835502 ]], dtype=float32),
#  '804': array([[0.       , 3.7604172, 4.9537783, ..., 2.8905613, 0.       ,
#          0.       ]], dtype=float32),
#  '961': array([[0.       , 0.       , 0.       , ..., 1.2810521, 0.       ,
#          1.4121206]], dtype=float32),
#  '880': array([[0.       , 1.1103752, 0.       , ..., 0.       , 1.4375095,
#          0.       ]], dtype=float32),
#  '805': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.015929]],
#        dtype=float32),
#  '904': array([[1.6836746 , 0.34416717, 0.        , ..., 0.        , 4.642839  ,
#          0.        ]], dtype=float32),
#  '746': array([[0.38329795, 0.        , 0.        , ..., 0.        , 4.4906282 ,
#          0.        ]], dtype=float32),
#  '919': array([[0.        , 0.        , 1.8947409 , ..., 0.        , 0.        ,
#          0.07314479]], dtype=float32),
#  '969': array([[0.        , 0.        , 0.35898438, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '806': array([[1.4303186, 3.9272888, 0.       , ..., 0.       , 0.       ,
#          0.6822318]], dtype=float32),
#  '91': array([[1.1217909, 0.4109553, 2.018618 , ..., 0.       , 0.       ,
#          1.2890029]], dtype=float32),
#  '851': array([[0.        , 0.98188174, 0.        , ..., 0.        , 0.        ,
#          0.86344457]], dtype=float32),
#  '768': array([[2.6484118, 6.76428  , 2.2242053, ..., 1.292635 , 0.8906082,
#          0.       ]], dtype=float32),
#  '764': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '955': array([[0.       , 0.       , 0.       , ..., 0.       , 0.4603898,
#          0.       ]], dtype=float32),
#  '861': array([[0.        , 0.        , 0.        , ..., 0.        , 0.24492782,
#          0.33384034]], dtype=float32),
#  '727': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '959': array([[0.        , 0.        , 0.31433147, ..., 0.        , 0.        ,
#          0.98220104]], dtype=float32),
#  '885': array([[0.       , 0.       , 0.       , ..., 0.       , 0.7580133,
#          3.7661319]], dtype=float32),
#  '884': array([[0.6862477 , 0.17494074, 0.        , ..., 0.        , 0.        ,
#          0.5986517 ]], dtype=float32),
#  '801': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '794': array([[0.        , 0.        , 0.        , ..., 0.        , 0.43228275,
#          0.        ]], dtype=float32),
#  ...}

# %% [markdown]
# ## Load the captions data

# %%
import pandas as pd

captions= pd.read_excel('/content/drive/MyDrive/image caption/images_info.xlsx')

# %%
captions.drop('id',axis=1,inplace=True  )

# %%
mapping = {}
for i in range(len(captions)):
  image_index= captions.image[i].split('.')[0]
  image_index = image_index.split('_')[1]
  mapping[image_index] = []
  mapping[image_index].append(captions.caption[i])

# %%
mapping
# Out:
# {'1': ['A beautiful young girl posing on a white background.'],
#  '4': ['One hand pointing, finger out, thumb up'],
#  '6': ['A beautiful young girl posing with a gray background.'],
#  '3': ['Medical stitches - puncture wound closed up'],
#  '15': ['A happy couple'],
#  '11': ['Young girl dancing on stage in tutu\nThis image was shot at high ISO, only use it as is, noise removal software was used.'],
#  '2': [' A man thinking with a white mask'],
#  '14': ['Businessman with lightbulb head - Thinking process and ideas in a business context'],
#  '10': ['Mother and baby in swimming pool'],
#  '5': ['my hand compared to ancient handprints of anasazi tribes'],
#  '18': ['Young boy dreams of being a superhero - Child imagination and creativity concept'],
#  '8': ['Sulky and angry young kid on the couch'],
#  '12': ['My Baby after bath'],
#  '16': ['Woman sketching a social network on virtual screen'],
#  '17': ['Nice dress (wedding)'],
#  '19': ['Girls with flowers and sharee'],
#  '24': ['Young woman holding purse smiles'],
#  '25': ['A beautiful young girl posing with a white background.'],
#  '20': ['A mother and her son sit by the Charles River in Boston, watching the ducks.'],
#  '28': ['Silhouette of woman flexing biceps'],
#  '23': ['happy swimmer'],
#  '29': ['Cute young toddler in a sweatshirt and a knit cap'],
#  '26': ['Attractive caucasian woman looking at camera.'],
#  '27': [' Cute little girls with wild hair and a look of mischief.'],
#  '30': ['Young boy in meditation position - tropical beach background'],
#  '32': ['Hand silhouette in heart shape with sunset in the middle and ocean background'],
#  '33': ['Tattoo says \\"Woman\\" in Chinese'],
#  '34': ['Stylish little girl eating a shaved ice snow cone.'],
#  '31': ['Helpful phone operator fields calls.'],
#  '40': ['Small child playing on the beach in the bright sun.'],
#  '38': ['Portrait of woman wearing sunglasses on the beach'],
#  '36': ['Little girl writing on blackboard - Learning and knowledge concept'],
#  '37': ['beautiful female torso on summer sea backgroung'],
#  '41': ['Child makes choices on computer touch screen.'],
#  '47': ['Profile of woman against white light box'],
#  '42': ['Little girl sticks out her tongue in play defiance.'],
#  '45': ['A romantic couple enjoying the sunset in a tropical island'],
#  '43': ['Hands typing on laptop keyboard - fuzzy looks'],
#  '48': ['Person connecting and sharing using social media networks - With speech bubbles featuring Facebook, Google Plus, Instagram, Pinterest, Linkedin, Skype, Tumblr, Twitter and Youtube'],
#  '50': ['young boy jumping of joy on beach background'],
#  '49': ['Businessman leader rising in a hot air balloon - Leadership concept'],
#  '52': [' Man in train station wearing black over ear headphones'],
#  '51': ['Red haired young woman with lip piercing looks at camera'],
#  '54': ['Child painting a watercolor'],
#  '53': ['Neck and back of a head of a sitting man with head turned'],
#  '57': ['Medical Doctor Studying the Human Body - Concept'],
#  '59': ['An call center professional wearing a white corporate attire'],
#  '58': ['A statue overlooking the Chicago skyline.'],
#  '56': ['Healthy young woman practicing yoga at sunset on the beach'],
#  '60': ['Back to school - Study concept'],
#  '55': ['Businessman Holding Light Bulb on Chalkboard\n'],
#  '61': ['Exitced young pretty woman headshot.'],
#  '62': ['A smiling young healthcare worker in his white clean uniform'],
#  '65': ['Sunset at the Honey Island Beach'],
#  '63': ['Sending a newsletter mail to your contacts - Online marketing concept'],
#  '64': ['Brown Haired Young Woman In Camel Jacket Looking At Camera'],
#  '69': ['Dark Roasted Cofee beans'],
#  '68': ['A girl making a big bubble'],
#  '71': ['Hand and lightbulb - Creativity and ideas concept'],
#  '67': ['Child playfully making circles around his eyes as he faces the camera with the sun in front of him.\n'],
#  '66': ['Young Woman Jogging at Sunset - Fitness and Health'],
#  '70': ['Street scene with pedestrians walking through bubbles'],
#  '72': ['Happy woman in red dress, vintage look.'],
#  '73': ['Businessman having an idea - Problem-solving in a business context'],
#  '74': ['Hand placing coins on a coin stack with upward arrow - Income and asset growth concept'],
#  '76': ['A boy in the desert sunset'],
#  '80': ['Young woman puts shopping bags over her shoulder.'],
#  '75': ['Medical Human Body Scan - Man and Technology'],
#  '78': ['Two kids in an old city street'],
#  '83': ['A young man wearing a brown casual shirt carying a black laptop'],
#  '81': ['Enjoying a glass of wine is always a pleasure.'],
#  '84': ['A woman with fours bags smelling a flowe'],
#  '77': ['Binary computer code on human face - Online privacy concept'],
#  '79': ['A young man kisses a young woman on the cheek.'],
#  '82': ['Cute Baby Boy'],
#  '86': ['Newborn Baby Feet in Mothers Hands'],
#  '87': ['A foot with part of a knit sock on the needles.'],
#  '91': ['Man with clock head - Slave to time concept'],
#  '85': ['Female Medical Doctor Analyzing DNA strands'],
#  '88': ['Sleeping beauty - A naked princess of the woods - Double exposure effect'],
#  '90': ['Woman in red dress looks over her shoulder.'],
#  '93': ['A beautiful young girl texting on a cell phone.'],
#  '94': ['Young woman thinking while facing camera'],
#  '92': ['Man sitting alone on bench looking at phone'],
#  '96': ['Only Love is Real - A Couple Embraces Under Light - Drawing with Copyspace'],
#  '95': ['Woman Working On Laptop - Close-Up of Hands'],
#  '98': ['Businessman holding a ball with information technology icons'],
#  '101': ['a happy young man wearing a brown business suit and a blue shirt'],
#  '97': ['Two Girls Cheering on the Beach - Double Exposure Effect'],
#  '100': ['Young woman leaning on ladder, looking at camera'],
#  '99': ['Woman in phone headset.'],
#  '102': [' Happy child drawing a sunny landscape - Childhood happiness'],
#  '106': ['Young woman stands, looking at camera.'],
#  '110': ['Woman with gift bags returns from shopping.'],
#  '105': ['Businessman climbing staircase - Concept of climbing the career ladder'],
#  '107': ['Man running on the beach at sunset'],
#  '103': ['Mommy and Johnny enjoy a day in the country.'],
#  '112': ['Young businesswoman standing with briefcase and files.'],
#  '114': ['Little boy looking upset, defiant look at camera'],
#  '108': ['Little girl painting a rainbow on the sky - Joy and happiness in childhood'],
#  '111': ['Young woman looking at camera.'],
#  '116': ['In order to spread more awareness towards the body painting arts, I have chosen to share some of my work as free stock photography.\nPlease make sure and credit the following if you use my images:\nModel: Rue\nPhotography and Body Painting by: Bryan Crump aka #crumpeffect\nBodypaint/Makeup used: Snazaroo and Mehron\nStudio: Facemakers'],
#  '117': ['Young boy in red and white striped shirt making wacky faces and fists'],
#  '115': ['Meditation - Mindfulness - Person Meditating at Sunset Over the Clouds'],
#  '120': ['A beautiful African American teen girl reading a book on a stone wall outside.'],
#  '121': ['Attractive young woman in blue dress with microphone.'],
#  '122': ['A femal doctor or nurse checking the blood pressure of a patient'],
#  '118': ['Cemetery scene With grave stones black & white image'],
#  '119': ['Anonymous businessman with derby hat'],
#  '123': ['Alpinist - Silhouette at dawn during a dangerous pitch'],
#  '126': ['The social network - People networking and creating bonds, contacts and connections'],
#  '128': ['Boy sees something shocking on the computer.'],
#  '129': ['Cute toddler emerging from fabric background with fabric copyspace.'],
#  '125': ['Boy jumping over the waves in the Pacific Ocean'],
#  '135': ['A pretty young girl posing with a white background.'],
#  '133': ['Smiling young boy in sturdy stance with hands in fists'],
#  '134': ['Woman naps with tired baby out of focus in background'],
#  '140': ['Toddler sized child sits on a spraying public fountain.'],
#  '137': ['Boy holding two thumbs up in approval'],
#  '136': ['Woman peering over her sunglasses at the beach.'],
#  '130': ['Meditation at Sunset'],
#  '131': ['LIttle girl watches computer screen.'],
#  '138': ['An doctor on his white clean overcoat'],
#  '144': ['Busy business guy on the phone, using his planner.'],
#  '141': ['A young employee working on a pile of paper works'],
#  '139': ['Cowboys riding horses at sunset - Western and Wild West concept'],
#  '142': ['blond girl playing tennis on open court'],
#  '143': ['Headshot of attractive young woman smiling at camera.'],
#  '147': ['Woman doing yoga.'],
#  '146': ['Girl jumping on trampoline and having fun'],
#  '145': ['An elderly man working on some paers and his laptop'],
#  '149': ['Little girl wearing princess crown gives puzzled look'],
#  '153': ['A beautiful young girl celebrating a birthday.'],
#  '150': ['Romantic couple watching the stars'],
#  '155': ['my son happy'],
#  '148': ['Conference table with seating in modern office building.'],
#  '152': [' Boy in striped shirt with arms crossed, looking upset or defensive'],
#  '154': ['a young man wearing turtle nack shirt confidently posed'],
#  '151': ['Human eye with clock - Time concept'],
#  '158': ['Model: Bina Sveda'],
#  '156': ['Pressing keys on a keyboard'],
#  '157': ["Superimposed newborn baby inside the mother's pregnant belly"],
#  '159': ['A business man on his mobile phone showing his money'],
#  '160': ['Senior eats his favorite sweets.'],
#  '163': ['Portrait of homeless man'],
#  '161': ['A man stands on railroad tracks converging in the distance.'],
#  '162': ['Happy Girl Jumping Down a PathOLYMPUS DIGITAL CAMERA'],
#  '165': ['Young kid making faces. Crossed eyes, extended tongue and two fists'],
#  '164': ['Little boy in striped shirt with vague neutral expression'],
#  '167': ['Businessman pointing at search bar on a virtual screen'],
#  '166': ['Young woman in blue dress sits on step ladder'],
#  '170': ['WOMEN IN LITTLE BLACK DRESSES'],
#  '168': ['A worker in a construction wearing safety clothing'],
#  '169': ['Prayer - Person Praying - Hands'],
#  '172': ["Image of the back of a man's head, pale and shaved"],
#  '171': ['Model in blue dress poses in parking garage'],
#  '176': ['Young couple relaxing on beach background'],
#  '179': ['Child getting soaked in a public park fountain.'],
#  '174': ['Young woman with gift bags.'],
#  '177': [' A beautiful young girl posing on a gray background.'],
#  '173': ['Hazy Looks - Romantic Couple at the Beach at Sunse'],
#  '178': ['Father holding his new baby'],
#  '175': ['Work Life Balance Concept'],
#  '182': ['In order to spread more awareness towards the body painting arts, I have chosen to share some of my work as free stock photography.\nPlease make sure and credit the following if you use my images:\nModel: Macie\nPhotography and Body Painting by: Bryan Crump aka #crumpeffect\nBodypaint/Makeup used: Snazaroo and Mehron\nStudio: Facemakers'],
#  '181': ['Young person looking happy'],
#  '180': ['Young kid looking angry with arms and fists up ready to fight'],
#  '187': ['A beautiful women stands tall with palms together as part of her yoga practice, which creates focus, peace, and a clear mind within the body.'],
#  '188': ['Woman in bright light looking at camera.'],
#  '191': ['Child holding the world in her hands - Future and happiness concept'],
#  '184': ['A beautiful African American teen girl posing in the woods.'],
#  '185': ['Promotion and marketing concept - Little people in front of a loudspeaker'],
#  '193': ['A man in a suit'],
#  '194': ['Young boy standing with arms crossed and a smile on his face'],
#  '189': ['An help for a new ride'],
#  '195': ['Woman makes cute face in black and white'],
#  '192': ['Businessman holding a virtual human brain in the palm - Skills, human development and IQ concept'],
#  '196': ['Little cute girl blowing dandelion seeds on chalkboard - Hope and aspirations concept'],
#  '197': ['A hand holds a bundle of twenty dollar bills'],
#  '203': ['Little boy in striped shirt looking at the camera, wildly sticking out his tongue'],
#  '202': ['Girl with Flowerss in Hand'],
#  '200': ['Businessman holding a globe with information technology icons in his palms - Information Technology concept'],
#  '198': ['Two little girls writing on a blackboard with science subjects - Learning, knowledge and education concept'],
#  '205': [' A beautiful young girl posing with a white background.'],
#  '199': ['Little girl on a boulder'],
#  '204': ['Celebrating life - A woman raises her arms at sunset on a deserted beach'],
#  '207': ['Mother holding wet baby with towel'],
#  '201': ['Two elderly men working on paper works and a laptop'],
#  '206': ['Starring out, always watching, always hoping through quiet contemplation.\\r\\n'],
#  '210': ['An Indian boy going school.\nwww.designscroller.com'],
#  '208': ['Rodins Thinker surrounded by question marks - Doubts and insecurities concept'],
#  '212': ['Human eye with planet Earth reflexion'],
#  '213': ['Stock out your tongue, make a funny face and cross your eyes'],
#  '209': ['Woman with arms raised at sunset on the beach'],
#  '214': ['Romantic couple kissing in love at sunset in a tropical island - Honeymoon scene'],
#  '216': ['A beautiful young girl posing on a gray background.'],
#  '215': ['A beautiful teen African American girl resting on bleachers with a bottle of water.'],
#  '219': ['Professional looking woman over city background'],
#  '218': ['A young man wearing business suit sitting on a chair and showing his money'],
#  '220': ['Little cute child running away from a funny monster - Child fears and insecurities concept'],
#  '222': ['Businessman drawing social network on virtual screen'],
#  '224': ['Little girl riding her bike in Cambodia'],
#  '223': ['Woman puts fist forward with engagement ring.'],
#  '226': ['A fashionable paor of high heel ladies shoes'],
#  '227': ['Model With A Fedora.'],
#  '230': ['Woman in workout gear and boxing gloves.'],
#  '231': ['Lonely at the Top - Lone Businessman at the Top'],
#  '233': ["just a jumpin' on our bed"],
#  '232': ['Man in a Bear Market - Losing Money in the Markets'],
#  '234': ['A cute young girl posing on a white background.'],
#  '235': ['Feet of a Bharathnatyam dancer.'],
#  '237': ['Proud assertive little girl solving a sum on blackboard - Learning and education concept'],
#  '240': ['A girl making many small bubbles'],
#  '245': ['Woman thinking and solving a problem'],
#  '244': ['B&W street portrait of homeless man in pensive state'],
#  '241': ['Young boy handstanding on jetty - Youth and vitality'],
#  '246': ['wonder what goes on behind blue eyes'],
#  '243': ['Woman Shopping Online'],
#  '236': ['bride and groom'],
#  '242': ['Young blonde woman dances to music.'],
#  '251': ['Coach prepares boxer at the Otis Grant Boxing Invitational on June 12, 2010 in Mississauga, Ontario [For news and editorial use]'],
#  '249': ['A young man wearing a blus shirt giving presents'],
#  '248': ['Model released triptych of a "1920\'s flapper."'],
#  '247': ['Sculpted Male Body - With Copyspace'],
#  '253': ['The wealthy and the others - Income inequality concept'],
#  '252': [" from India's monsoon photo"],
#  '254': ['Feet of an athlete running on a deserted road - Training for fitness and healthy lifestyle'],
#  '258': ['Working in the green fields'],
#  '255': ['Man in kayak going down rapids'],
#  '260': ['Model in pink and black dress.'],
#  '259': ['Ariadna Gil on \\"Pan\\\'s Labirinth\\" Fotocall, Sitges Festival 2006'],
#  '263': ['Model released photo of a pretty woman shopper'],
#  '262': ['Dressed up woman gun in steampunk style'],
#  '256': ['Hiring New Employees - Job Interview and Recruitment Selection Idea'],
#  '265': ['Young woman exclaiming her excitement'],
#  '261': ['Armed Man with Background Explosion\n'],
#  '266': ['Expressing Doubts - Interrogation Marks - Hand Drawing a Person Having Doubts'],
#  '268': ['School Children look our a window in Northern Thailand'],
#  '269': ['Mother and son sharing a moment on the beach in Florida'],
#  '271': ['Brunette girl is smiling and posing for a photo.'],
#  '270': ['Man on top of the mountain with raised arms'],
#  '267': ['People in space at the Tate Britain'],
#  '274': ['Tom Sawyer and Huck statue in Hannibal, Missouri. \\r\\n'],
#  '273': ['Baby Easter shots'],
#  '278': ['Hit the Road - Long Distance Runner on the Road - Close-up - Athlete Running on Empty Road at Sunset'],
#  '272': ['Businessman touching virtual screen'],
#  '275': ['Boxing woman punches towards camera.'],
#  '276': ['a young man wearing turtle nack shirt with his arms wide open'],
#  '281': ['A young boy playing in the sand and surf.'],
#  '277': ["Mother cleaning child\\'s face at party\n"],
#  '285': ["Children\\'s football"],
#  '280': [' Human eye with barcode - Big data concept'],
#  '283': ['A beautiful African American teen girl posing by a lake.'],
#  '279': ['Steampunk girl with gun on old train car'],
#  '284': ['Vintage look blonde woman blows a kiss to camera.'],
#  '286': ['A set of cleaning equipments'],
#  '290': ['a sweet view of little sleepy toes'],
#  '288': ['tourist woman shoots photos on vacation'],
#  '289': ['A pastor holding up to round wedding rings'],
#  '291': ['Empty office workstations.'],
#  '292': ['Jolly girls with flowers'],
#  '294': ['Bengali Man'],
#  '295': ['a pink martini being poured'],
#  '293': ['7 year old girl climbing a rock wall, silhouetted by the sun'],
#  '297': ['Woman with red fingernails hides eyes, shows off nails'],
#  '298': ['photos of a girl'],
#  '302': ['Vintage look blonde woman sitting in polka dot dress'],
#  '300': ["from India's monsoon photo"],
#  '299': ['Businessman holding plant sprouting from a handful of golden coins'],
#  '301': ['Computer programmer working at the desk - HTML5 PHP Javascript Android Webdesigner'],
#  '296': ['Wonder what they were thinking.'],
#  '257': ['Social media and marketing campaign concept'],
#  '304': ['A beautiful teen African American girl running by a fence.'],
#  '303': ['Young child looks out the window.'],
#  '305': ['Human eye viewing data on virtual screen - Biometrics concept'],
#  '306': ['Architect looking at plans, wearing hard hat'],
#  '309': ['A cute young girl posing with a beach ball.'],
#  '312': ['LIttle boy giving the side eye'],
#  '308': ['Girls in Bengali New Year'],
#  '316': ['Little cute girl having a good idea on the blackboard - Learning and discovery concept with lightbulb'],
#  '311': ['Hand of a businessman holding Earth globe - Globalization concept'],
#  '314': [' At a crossroads - Decisions and choices concept with large arrow signs'],
#  '318': ['Portrait of a beautiful African American teen girl posing by a lake.'],
#  '317': ['Woman looking at camer, tipping black top hat'],
#  '321': ['A set of construction tools and safety devices'],
#  '320': ['Young boy looking silly or sickly with arms crossed on tongue out'],
#  '319': ['People at the Main square in Bratislava, Slovakia'],
#  '323': ['Two girls in a country-side'],
#  '315': ['Hand creating a lightbulb with green tree - Ecology and life concept'],
#  '322': ['Portrait of a beautiful African American teen girl posing on a stone wall.'],
#  '327': ['People shopping at an open air market in Greenwich Village, New York City'],
#  '325': ['A young couple hold hands at the beach.'],
#  '330': ['a happy young man wearing a brown business suit and a green polo shirt'],
#  '329': ['A boat on Lake Michigan, near to Belmont Harbor.'],
#  '326': ["Close up curves of woman's body"],
#  '331': ['Johnny enjoys a day at the area park.'],
#  '328': ['Businessmen acting like superheros and tearing shirts off with copy space'],
#  '333': ['Woman in a black dress plays the alto saxophone'],
#  '334': ['Single flower bloom in an open hand'],
#  '335': ['A young woman talking on his mobile phone'],
#  '337': ['A young woman wearing a blu turtlr neck shirt flexing her muscles'],
#  '339': ['School students testing'],
#  '332': ['Zac Alexander enjoying Seal Beach, CA\\r\\n(released)'],
#  '338': ['Statue of a pope'],
#  '340': ["a doctor checking a little girl's ear"],
#  '342': ['Greedy businessman as a great white shark - Greed Concept'],
#  '343': ["Zac Alexander relaxing in his inner tube. Smilin\\' Zac"],
#  '347': ['Clown juggles balls in the park'],
#  '341': ['man in a public plaza'],
#  '345': ['Unhappy woman sitting on a bench'],
#  '344': ['Joining hands - A child and an adult join hands on chalkboard'],
#  '348': ['a girl playing with a hoola hoops'],
#  '351': ['Interior of sparsely populated parking garage'],
#  '355': ['A cute young girl posing with a white background.'],
#  '346': ['Standing out from the crowd - Under the spotlight and individualist concept'],
#  '352': ['Child bathing in a natural sea pool with the help of her mother'],
#  '353': ['Tedtty and Michael with the horses'],
#  '349': ['Hand writing the words Team Work on virtual screen - Team work concept'],
#  '357': ['A Network of People - Networking Concept'],
#  '354': ['Little girl painting the sky - Child joy and happiness concept'],
#  '358': ['Chinese writing on a stone plaza'],
#  '362': ['A young man wearing a blue shirt looking through binoculars'],
#  '359': ['A day at the beach in Cocoa Beach Florida'],
#  '361': ['Young woman in Yellow Collared Shirt looking herself reflection in mirror at home'],
#  '356': ['Women With Love'],
#  '360': ['Businessman rolling huge ball up hill - Fighting adversity concept'],
#  '363': ['Young woman waits for rain with orange umbrella'],
#  '365': ['Young woman wants you to be quiet'],
#  '364': [' Woman drawing a network over a virtual world map'],
#  '367': ['Carriage waiting after wedding'],
#  '369': ['A Lady wearing a pink dress eating chocolates'],
#  '371': ['Illustration concept for mobile apps - People communicating through their phones'],
#  '368': ['A red rose on top af a musical piece'],
#  '366': ['Businessman on the summit surrounded by hot air balloons - Ambition at the top concept'],
#  '372': ['Under the umbrella - A couple kisses at sunset in Vale do Lobo beach, Algarve, Portugal'],
#  '370': ['Young Female Runner Stretching before Jogging - Women Fitness and Health'],
#  '374': ['Job Interview - Multiple Applicants with Copyspace'],
#  '377': ['Max Alexander (released) peeking out from behind plant fronds on the big island of Hawaii.'],
#  '376': ['Kids socializing on the pier'],
#  '378': ['Joy and Happiness - Young Woman Jumps at Sunset'],
#  '383': ['young girl playing with a golden Retriever'],
#  '381': ['Woman with sword in a workshop'],
#  '375': ['A child pretends reading a book accompanied by a doll'],
#  '382': ['Businessman touching virtual social network'],
#  '379': ['Child Chasing Cupcake - Healthy Diet versus Child Obesity'],
#  '380': ['Anonymous businessmen with bowler hats'],
#  '384': ['Engagment picture posed for a proposal'],
#  '387': ["Can't pay for dinner? Grab a sponge and get to work on those dishes Mister."],
#  '390': ['A pretty young girl holding a toothbrush.'],
#  '386': ['A child playing with his scooter in a Chicago park.'],
#  '389': ['Conceptual Landscape Architecture planting plan - example of a composite image in perspective'],
#  '391': ['Sharing with Friends Through Social Media'],
#  '388': ['Father Love - A Father Holding Her Baby Girl'],
#  '392': ['A happy baby sitting outside in the grass.'],
#  '394': ['A beautiful young woman dressed in business attire posing near a building.'],
#  '395': ['Man with his hands behind his back'],
#  '393': ['Colorful Christmas gifts and christmas decors'],
#  '399': ['unknown climbers around the world'],
#  '396': ['Job interview - Illustration with Copyspace'],
#  '397': ['Girl laying on a pillow.'],
#  '398': ['Illustration of a kid playing soccer in Rio de Janeiro - Brazil'],
#  '401': ['Black dog, kids tubing, girls graduating.'],
#  '402': ['Listening to headphones on high tech LED background.\n'],
#  '406': ['Close up woman body and hands'],
#  '404': ['red whole strawberries'],
#  '407': ['A beautiful young girl with a thoughtful expression.'],
#  '405': ['Young People Working on Their Computers'],
#  '408': ['Young woman with hands clasped, looking at camera'],
#  '410': ['A door with a glass cross capturing the photographer in its reflection.'],
#  '411': ['Men Running at Sunset - Double Exposure Effect'],
#  '412': ['Taking a photo with smartphone - Happy boy jumping into river'],
#  '413': ['Upset man flipping off the camera'],
#  '416': ['Child Running Sun Reflecting on Beach'],
#  '414': [' Johnny and mommy enjoy some relaxing time together. Not many pictures of mommy and son because mommy is the photographer in the family.'],
#  '409': ['Multiethnicity colleagues looking at their mobile phones during the break time'],
#  '418': ['Young Attractive Woman Training with HTRX Fitness Straps in the Gym'],
#  '421': ['Young woman dances to music in headphones.'],
#  '419': ['a young man wearing green shirt with his hands in his pocket'],
#  '417': ['Mechanic fixing a car in garage'],
#  '420': ['Japan flag with businessman showing a superhero suit - pulling suit'],
#  '423': ['Biker waving on a Harley Davidson - Grunge look'],
#  '426': ['A couple holding hands showcasing engagement ring resting on a rock'],
#  '425': ['Young blonde woman in black and white dress.'],
#  '428': ['catching a juggling ball'],
#  '427': [' Alternative steampunk woman with gun isolated on white'],
#  '424': ['Children eating chicken with their hands and smiling'],
#  '430': ['A local church at the end of a beautiful fall day, viewed from between two headstones.'],
#  '429': ['Loving Father Kissing Baby Girl - Colorized'],
#  '431': ['Young Woman on the Beach at Sunset with Raised Arms'],
#  '432': ['Thumbs up and thumbs down'],
#  '433': ['A day in a Japanese market.'],
#  '434': ['A stem of a beautiful red rose'],
#  '435': ['Bright traffic on the streets of Havana, Cuba'],
#  '436': ['Man remembering his girlfriend - Double Exposure Effect'],
#  '441': ['A woman playing the piano'],
#  '438': ['A young schoolgirl reading a book outside.'],
#  '439': ['Model released mosaic style photo of a pretty woman smiling'],
#  '442': ['Photo of Holly Jean in a flower garden in the STL area.'],
#  '440': ['Young woman listens to music.'],
#  '447': ['Human Portrait'],
#  '445': ['Boy climbing and playing'],
#  '444': ['Into the Light - Parents Hold Hands with their Child'],
#  '449': ['Thoughtful Woman on the Mountain Face'],
#  '448': ['Businessman touching virtual screen with world map'],
#  '446': ['hoboclown detective,Flash Mc Cool in his repose on his rock'],
#  '450': ['Young woman with steampunk gun looking at the camera, on white'],
#  '451': ['A person and the respective personal connections in a social network - Social network concept'],
#  '453': ['A cute young girl posing with an angry expression making a fist.'],
#  '452': ['Craftsman at work'],
#  '455': ['Businessman rising by holding a balloon - Promotion and career concept'],
#  '454': ['Businessman holding a jigsaw lightbulb - Ideas and creativity concept'],
#  '456': ['Young model stands in black and pink dress.'],
#  '457': ['Fisherman at sunrise'],
#  '458': ['Family'],
#  '459': ['Pretty young woman in the studio looking up.'],
#  '461': ["Chopin's Grave in Pere Lachaise"],
#  '462': ['Young woman standing and looking up with arms at neck.'],
#  '463': ['Young african american model stands in black dress.'],
#  '464': ['Model in pink dress stands in empey warehouse'],
#  '467': ['A pretty young girl dressed for the 4th of July holding a blank blue sign.'],
#  '472': ['Passion - Young Couple in Love'],
#  '469': ['Attractive young woman with microphone.'],
#  '470': ['Close up woman body and folded hands'],
#  '475': ['Eye and eyelashes'],
#  '473': ['Looking up past man to cloudy sky'],
#  '474': ['Finger Art Broken Heart'],
#  '466': ['Tuileries gardens in France, Man with sailboats'],
#  '478': ['Cemetery monument at sunset'],
#  '471': ['Young musician with sunglasses at microphone.'],
#  '477': [' Silhouette of a child holding the sun in his right hand'],
#  '480': ['Under Bosphorus Bridge, Istanbul'],
#  '468': ['Study of Maths and Abstraction - Concept'],
#  '476': ["Close up of a woman's eye with hazel green eyes."],
#  '479': ['A young latino boy playing on a playground.'],
#  '481': ['Business improvement site'],
#  '483': ['Artist painter painting self-portrait - art and creativity concept version 2'],
#  '487': ['Man Standing on the Top of the Mountain Above the Clouds - Victory and Achievement'],
#  '486': ['Young woman with gold fingernail covers looking at camera'],
#  '484': ['four toasted bagels and shiny metalic bread toaster'],
#  '482': ['Portrait of a beautiful sweet girl smiling on the beach'],
#  '485': ['Pills on a palm'],
#  '491': ['Blond woman with hand on her glasses'],
#  '489': ['Girl in treany clothes looks at camera'],
#  '490': ['Friendly young brunette girl, looking at camera'],
#  '488': ['Male Runner in the Countryside at Sunrise'],
#  '496': ['vacation thailand'],
#  '492': ['Man on the Summit Embracing a Brave New Day'],
#  '497': ['Businessman holding a lightbulb - Ideas and creativity concept with concentric rings'],
#  '498': ['Women jogging outdoors'],
#  '500': ['Attractive young woman in blue dress.'],
#  '503': ['Little Blonde Girl Kissing Pregnant Mother'],
#  '494': ['A woman stands against and opens a garage door.'],
#  '501': ['Sleeping Beauty - Woman Asleep - Tinted Looks'],
#  '499': ['Sweet older brother hugging his young sister on the grass'],
#  '493': ['Some boys legs running on a boardwalk on a sunny day'],
#  '504': ['Young woman drying her hair with a hair dryer'],
#  '507': ['Woman in a green dress plays the alto saxophone'],
#  '502': ['Hazy Vintage Looks - Couple Walking Hand in Hand'],
#  '506': ['a portrait natural shot of a boy'],
#  '505': ['Kiss Me - First Kiss First Love'],
#  '508': ['Couple in love Kissing over New York - Double Exposure Effect'],
#  '510': ['Man with gas saw cutting down a tree'],
#  '512': ['Young Couple In Love'],
#  '513': ['Man having doubts facing a staircase - Should I stay or should I go concept'],
#  '516': ['Young woman in purple dress stands in splashing water space scene.'],
#  '511': ['Female Runner Feet - Running on the Road - Women Fitness'],
#  '514': ['A well loved toy girl figure wearing a crown.'],
#  '515': ['The Cuban capitol and colorful traffic'],
#  '521': ['Kite Surfing'],
#  '518': ['Footsteps in the sand.'],
#  '519': ['Mother in the hospital with newborn baby'],
#  '520': ['strolling through Veterans Park in Milwaukee; saw this kite flyer'],
#  '522': ['Attractive young red haired woman looking at camera'],
#  '523': ["Nothing brings a smile to a mother's face than to see her child laughing and smiling."],
#  '527': ['An alley in the small town of Shimizu, Japan.'],
#  '530': ['A woman in a black dress with her chin in her hand.'],
#  '524': ['Closeup of very red eye'],
#  '525': ['Young Asian man standing in stylish blazer, looking at camera'],
#  '532': ['Free-climber rising at sundown'],
#  '526': ['Child holding and pointing forward a paintbrush'],
#  '528': ['Deliciously grilled pork steak'],
#  '535': ['Little Angry Girl - Shut Up Gesture'],
#  '533': ['Johnny visited the Petting Zoo... for the first time.'],
#  '534': ['Hazy Vintage Looks - Girl Looking Over the City'],
#  '537': ['Woman in studio sitting on white hexagonal shaped block'],
#  '536': ['Cute baby toes'],
#  '541': ['Cute Child - Cute Baby Boy'],
#  '542': ['Businessman holding Earth globe - Globalization concept'],
#  '540': ['Kids see something on the laptop that makes them very excited'],
#  '545': ['Joining the dots - Problem-solving concept'],
#  '539': ['child at play, looking through hands'],
#  '544': ['Hawaii Beach'],
#  '547': ['Young man wearing a black suit with headphones.'],
#  '548': ['Kids on a twister (in the entertainment park)'],
#  '549': ['A group of latino kids posing on a playground.'],
#  '550': ['Women poses around a tree.'],
#  '551': ['Child hit by sun rays bathing in golden water'],
#  '555': ['Locked rusty gates in HDR of empty country road.'],
#  '553': ['Twin girls with opposite emotions (or the two sides of a Mets fan)'],
#  '556': ['Business People on Cogwheels - Workforce and Teamwork Concept'],
#  '559': ['Woman sketching a businessman climbing stairs - Career and success concept'],
#  '554': ['Man using a tin can telephone'],
#  '561': ['A cute young girl holding a blank sign.'],
#  '558': ['Kiwi fruit sliced and whole'],
#  '560': ['Trapped - Woman Trapped in a Relationship'],
#  '565': ['Angel Cabrera at the Accenture Match Play Championship, Marana, Arizona 2010'],
#  '564': ['Young woman works out with small weights.'],
#  '566': ['Stylish young Asian man with hands in his pockets looking at camera'],
#  '562': ['Urban Scene - People Crossing Avenue - Blurry Looks'],
#  '568': ['A woman stands while her young daugher gives her a hug'],
#  '571': ['The statue of Arthur Fieldler, Boston Pops conductor, in the Esplinade, sitting quietly covered in snow.'],
#  '567': ['Businessman with stopwatch head - Time concept'],
#  '572': ['Young woman in flower print dress looking at camera'],
#  '569': ['Johnny loved to tickle the ivory with his dad whenever he could.'],
#  '570': ['Woman Walking Alone on the Beach - Vintage Looks'],
#  '576': ['Model Suvro, Dhaka, Bangladesh'],
#  '574': ['sliced ripe yellow mango'],
#  '577': ['A man wearing a red shirt taking photos with a digital camera'],
#  '579': ['Father Touching Hand of Newborn Baby'],
#  '578': ['Gymnastics - The Flexible Human Body - Contorted Beautiful Woman Posing'],
#  '580': ['A cute young girl posing outdoors.'],
#  '584': ['As a baby, Johnny became fascinated by water... as a toddler, this fascination has waned.'],
#  '582': ['green and red apples in a basket'],
#  '589': ['Woman Drowning - Double Exposure Effect'],
#  '587': ['Young man happily listens to music.'],
#  '585': ['A young musicial with a black suit lying with musical instrument in a black case'],
#  '588': ['A woman with tattoos plays pinball'],
#  '586': ['A bouqet or red and white roses'],
#  '583': ['Sweet little child in a meadow with wild purple spring flowers'],
#  '591': ['Surprised man looking into binary code - The online privacy problem'],
#  '592': ['School Children Testing'],
#  '593': ['Tea leaves plucking in a TEA garden of India'],
#  '597': ['Close-up portrait of a beautiful girl posing outdoors.'],
#  '594': ['Businessman eating a doughnut in formal clothing'],
#  '595': ['Lone wind tubine stands in field.'],
#  '590': ['Primary School Classroom mobile upload'],
#  '602': ['A young businessman with crossed arms isolated on a white background.'],
#  '596': ['A crowded beach filled with tourists enjoying a beautiful sunny day'],
#  '601': ['Distant view of Havana, Cuba'],
#  '600': ['Going up and down on an escalator.'],
#  '606': ['A fashionable high heel ladies shoe'],
#  '598': ['Children traditional dressed near Cajamarca (Peru)'],
#  '599': ['Clown with red nose making faces'],
#  '604': ['A cute young girl with a thoughtful expression.'],
#  '603': ['Woman spray paints graffiti on concrete.'],
#  '605': ['Marriage Ritual'],
#  '608': ['Woman looking at camera as her ice cream fell on the road'],
#  '616': ['Young woman in blue top with arms up'],
#  '607': ['Young man is upset'],
#  '614': ['Craftsman is sculpting a wood.'],
#  '611': ["Johnny don's his hat for a trip on the sea"],
#  '613': ['Hazy Vintage Looks - Young Woman with Glasses - Attentive - Classroom'],
#  '610': ['Johnny developed a love of photography young.'],
#  '612': ['Two lovers watching a fiery sunset in Algarve, Portugal'],
#  '609': ['Handstanding on the beach at sunset - Youth and vitality'],
#  '618': ['A beautiful young girl isolated on a white background.'],
#  '617': ['A professional camera with a set of lenses'],
#  '622': ['A cute young girl running on a track field.'],
#  '620': ['Sexy asian woman wearing a costume - 70s style'],
#  '621': ['A dancer performs ballet on a construction site.'],
#  '619': ['Young woman with crossed arms looks at the camera.'],
#  '623': ['Woman wearing black over ear headphones around neck'],
#  '624': ['Young cool couple standing together'],
#  '629': ['Johnny loved the pool in Wisconsin Dells, but insisted that he had to wear his "Sponge Bob" swim trunks.'],
#  '626': ['Johnny loved to watch the ants roam the driveway.'],
#  '627': ['A woman with tattoos plays pool.\n'],
#  '625': ['Couple Kissing Laying on the Grass'],
#  '631': ['A woman hides under a tree in the woods'],
#  '630': ['Johnny lounging in bath'],
#  '632': ['The Grim Reaper tries to lure the next victim'],
#  '628': ['Woman Unbuttoning Shorts with Fishnet Stockings - Soft Looks'],
#  '635': ['Red car on the streets of Havana, Cuba'],
#  '639': ['A young man with a red electric guitar'],
#  '634': ['A cute young girl posing with a soccer ball.'],
#  '644': ['Young woman looking at the camera, texting'],
#  '642': ['Girl walking on the road with hot air balloons'],
#  '637': ['Medical Doctor Performing DNA Analysis and Sequencing - Illustration'],
#  '643': ['man,people,human closeup'],
#  '640': ['Jumpstart Your Training - Strenght Training for Women'],
#  '646': ['Young Man at Sunset on the Beach'],
#  '638': ['After chasing them around the farm, Johnny finally catches one.'],
#  '645': ['A beautiful young girl holding a blank green sign.'],
#  '641': ['Children playing in the ocean'],
#  '647': ['Woman wearing boxing gloves throwing punch to a man'],
#  '650': ['Young adult man cutting a pizza with fork and knife to eat in a restaurant'],
#  '648': ['Bedouin arabic children in Egypt'],
#  '651': ['Pretty young woman stands with handbag'],
#  '653': ['Woman in colorful clothes looking at camera.'],
#  '649': ['Old man'],
#  '656': ['While on vacation in Myrtle Beach, we went Dolphin watching... these are the before pictures.'],
#  '652': ['Isolated psychedelic eyes.\n'],
#  '655': ['Man riding a dart through the sky - Leadership and sense of purpose concept'],
#  '654': ['Three people came back from snorkeling in the Atlantic ocean'],
#  '659': ['Young woman playing the saxophone in a stylized city street'],
#  '658': ['Scary Face'],
#  '661': ['Surfing in Florida at Cocoa Beach'],
#  '662': ['people in the water'],
#  '660': ['Funny couple kissing on bed in midst of acrobatic yoga move.'],
#  '665': ['Bullfight in Sevilla (Spain)'],
#  '667': ['A cute young girl posing with a blank brown sign.'],
#  '670': ['Woman in black dress plays the alto saxophone'],
#  '666': ['Businessman holding a lightbulb - Ideas and creativity concept'],
#  '668': ['A lone person observes an hot air balloon at sunrise'],
#  '673': ['A child sitting on a clinic bed for her check up'],
#  '671': ['Brunette standing with hand on hip'],
#  '674': ['A young man using his mobile phone to send a message or shoot a photo'],
#  '672': ['Cleaning out the flue in preparation for winter'],
#  '678': ['Local fishing in Northeastern of Thailand'],
#  '681': ['Johnny picked up his love of photography from his mommy. He is pretty good too.'],
#  '679': ['Businessman Thinking about Money and Markets'],
#  '677': ['Cupped bloody hands holding an apple'],
#  '680': ['Career Advancement - Competition Among Coworkers - Concept'],
#  '682': ['Observation Deck of World Trade Center - New York City'],
#  '675': ['Man in kayak on a river'],
#  '683': ['A young man wearing cowboy hats and a leather jacket showing off his money'],
#  '685': ['Standing young woman in purple dress wears sunglasses.'],
#  '688': ['A beautiful young girl reading a book.'],
#  '684': ['A cute young girl on a track field preparing to race.'],
#  '689': ['A Young Woman Wearing a Green Jacket Drinking a Cup of Coffee'],
#  '690': ['Parachutists team performing swoops at an airshow'],
#  '686': ['A confident look from a young man wearing a leather jacker and shades'],
#  '692': ['Companionship - older brother embracing little sister on the pier'],
#  '694': ['Polygonal hand displaying victory sign - With copyspace'],
#  '691': ['Green limes whole and sliced'],
#  '696': ['Runner crossing a metal bridge at sunrise during morning training'],
#  '693': ['Head shot of attractive African American woman, looking over shoulder'],
#  '697': ['Boy with handprint over his mouth, symbolizing silence or censorship'],
#  '699': ['A young man wearing blue polo Drinking a cup of coffee'],
#  '698': ['a black & white close-up picture of a mother breastfeeding baby'],
#  '695': ['Prize Winner - Young Man Smiling with Bag of Money'],
#  '702': ['Medical Doctors Performing DNA Analysis\n'],
#  '705': ['Full length photo of woman in retro dress looking at camera'],
#  '703': ['Shot of couple holding hands showcasing engagement ring'],
#  '712': ['A woman with tattoos plays pool.'],
#  '710': ['Young man listening to music looks up.'],
#  '714': ['Wearables - The Great Smartwatch Scramble with copyspace'],
#  '717': ['A cute young girl texting on a cell phone.'],
#  '706': ['Musician Playing Banjo Guitar'],
#  '707': ['Baby Feet'],
#  '713': ['Woman Alone at the Top of the Mountain'],
#  '711': ['Child wearing a hat on a lavender plantation in Provence, southern France'],
#  '709': ['dispensing a cup of coffee'],
#  '716': ['Elvis statue in Las Vegas on the strip'],
#  '715': ['Woman with Raised Arms at Sunset on the Beach'],
#  '720': ['Young Woman Drinking Sparkling Water at the Beach - Health and Fitness'],
#  '721': ['Traditional Christmas Decoration'],
#  '719': ['Silhouette of Young Woman - Warm-Up exercise on the Beach at Sunset'],
#  '722': ['A pretty young girl reading a book.'],
#  '718': ["Johnny's aunt has a dairy farm in\nWisconsin and Johnny absolutely loves to visit and explore."],
#  '725': ['Baby Boy Winking Eye Mischievously'],
#  '724': ['Blind love'],
#  '723': ['Little girl on the beach at sunset - Summer vacations'],
#  '728': ['Young beautiful girl - A princess of the snowy mountains with double exposure effect'],
#  '726': ['Wearable and smartwatch technology - Concept'],
#  '729': ['Young elegantly dress woman looks at camera.'],
#  '727': ['Three young girls celebrating a birthday.'],
#  '734': ['Businessman Riding a Set of Arrows - Bull versus Bear Markets Concept'],
#  '730': ['A young woman with glasses working on her laptop at home'],
#  '731': ['Music fans listening to their favorite musicians at a concert.'],
#  '737': ['sliced peached and a whole peaches'],
#  '735': ['Love is red - Valentines day concept'],
#  '741': ['A picture of a boy discovering how cold snow is!'],
#  '739': ['Footprint in the Sand'],
#  '738': ['A young man wearing a purple shirt looking through binoculars'],
#  '746': ['Students Taking an Exam'],
#  '743': ['A wood walkway wounds its way around a forest at Dingman s Ferry Falls in Pennsylvia in autumn.'],
#  '745': ['A little boy and a little girl running on the beach'],
#  '748': ['A boy on a bridge'],
#  '747': ['Johnny really loved the petting zoo.'],
#  '751': ['Young Couple in Love - Outdoors'],
#  '749': ['Woman sits with her daughter on her lap'],
#  '754': ['Medical doctor pointing to an x-ray image'],
#  '750': ['Group of women in traditional clothes in their village - Masai Mara, Kenya'],
#  '756': ['A young man wearing a red and white shirt tryng to communicate'],
#  '753': ['Young woman wearing headphones.'],
#  '755': ['person walking on beach'],
#  '752': [' Many hands displaying the victory sign with v-shaped fingers - With copyspace'],
#  '763': ['Exitced young pretty woman in blue dress.'],
#  '757': ['A young woman keeps warm with hood and gloves.'],
#  '759': ['Business Meeting - Discussing Plans Over Table - Young Entrepreneurs'],
#  '758': ['Father Holding Hands with Little Daughter'],
#  '760': ['Two cute young girls reading books outdoors.'],
#  '761': ['Sexy woman laying down on bed with surrounding circles'],
#  '762': ['Business Meeting - People Discussing Business - Colorized'],
#  '765': ['A caucasian woman posing with a smile as looking at camera'],
#  '764': ['A ring with dozens of diamond wraping around a thick band of white gold.'],
#  '767': ['A young man wearing a leather jacket offering to shake his hands'],
#  '768': ['Abraham Lincoln birth place. National Historic Site in Kentucky.'],
#  '771': ['Young cool guy posing in a leather vest and top hat'],
#  '766': ['Girls getting ready for prom.'],
#  '770': ['Two men make different faces as covered with white flour'],
#  '772': ['Colorful plastic bottles with energy drink'],
#  '774': ['Into the atmosphere - Paragliding over mountain ridge'],
#  '769': ['Firefighter Fighting a Raging Wildfire - Silhouette'],
#  '773': ['Craftsman is working on wood. Nice rare photo, but there is no bigger image.'],
#  '775': ['Born to Run - Female Athlete Sprinting - Ink Drawing-Style Illustration'],
#  '776': ['Business Meeting - Colorized Hazy Looks'],
#  '777': ['A tall cemetery monument at sunset.'],
#  '782': ['Sad little boy waiting outside'],
#  '780': ['Medical doctor examining a chest PA x-ray image\n'],
#  '778': ['Wall Street Businessman - Retro styled looks for tycoon concept'],
#  '779': ['child at play'],
#  '781': ['Little Girl Learning To Swim with Life Vest'],
#  '786': ['A beautiful young woman dressed in business attire posing near a building'],
#  '783': ['wedding dress'],
#  '785': ['Cooking - A Man Chopping Veggies'],
#  '784': ['Eureka moment - Woman having an idea'],
#  '792': ['Woman in green and black dress plays the alto saxophone'],
#  '788': ['A close up of a young caucasian man'],
#  '790': ['shot of London Big Ben & buses passing and people walking'],
#  '791': ['Businessman with bar chart and lightbult - Asset Growth Concept'],
#  '795': ['A hand being held out for a handshake.'],
#  '797': ['travel in thailand'],
#  '793': ['A young country singer wearing a white and brown checkered long sleeves shirt'],
#  '796': ['Hands on a pregnant belly'],
#  '794': ['Cowboy in a saddle with a coiled rope'],
#  '801': ['Cheerful Smiling Child Having Ideas - Creativity and Imagination'],
#  '802': ['Doctor examining and holding an x-ray image on his hand'],
#  '800': ['Head shot of attractive African American woman.'],
#  '803': ['A cute guy sells perfumes'],
#  '806': ['Mystic woman in a blue dress enjoys the night.'],
#  '805': ['Young woman wearing headphones, looking at camera.'],
#  '808': ['Young brunette woman in red dress points at camera'],
#  '804': ['House in small neighbourhood that caught on fire'],
#  '807': ['Silhouette of a rock-climber'],
#  '810': ['A happy romantic couple with a bouqet of flowers'],
#  '811': ['A woman enjoys music during listening with headphones.'],
#  '813': ['Cute Little Girl Showing Thumbs Up - Creativity and Great Ideas'],
#  '809': ["Johnny loved the kitties at my sister-in-law's farm. And, these little fella's didn't mind being carried upside-down."],
#  '817': ['A Young Woman Wearng a thick Winter Clothing'],
#  '814': ['Skyline of the city of Calgary, Canada'],
#  '815': ["Oscar Wilde's Gravesite at Pere Lachaise"],
#  '819': ['A cute young girl on a track field.'],
#  '818': ['Brunette woman wearing a sunglasses on the back of a head'],
#  '822': ['Businessman through the keyhole - Creative solutions concept'],
#  '821': ['Woman in small black dress plays the alto saxophone'],
#  '820': ['Asian model isolated on white background'],
#  '826': ['A cute young girl posing on white background.'],
#  '827': [' Street band'],
#  '828': ['A pretty young girl brushing her teeth.'],
#  '825': ['Child preparing to eat bread & butter'],
#  '831': ['Views of people walking'],
#  '830': ['An Adult Human being walking in a bunny onesie'],
#  '834': ["While on holiday in the south of France we tried to visit one of the ancient cave's with pre-historic paintings but they were full up. Down the road was a museum with exact replica's that we visited instead. I probably wouldn't be allowed to take pictures of the originals and even if I were, my camera struggles in low light conditions. Long story short, this is one of the replica's (scientifically reproduced to great accuracy)"],
#  '832': ['Little girl fishing and smiling'],
#  '833': ['A young girl rowing around a lake.'],
#  '835': ['Johnny decided to help out with some yard work.'],
#  '840': ['A beautiful young girl holding a teddy bear.'],
#  '837': ['Woman wears headphones on her neck and looks up.'],
#  '841': ['Young Adult Women doing thigh and pilates exercises on yoga mats in a gym'],
#  '844': ['Young steampunk woman stands in costume'],
#  '838': ['A woman poses with a large wall of graffiti'],
#  '842': ['Guy in boots and jeans steps in gum'],
#  '845': ['Young boy with black handprint over his mouth, symbolic of censorship or supression.'],
#  '843': ['A police helicopter hovers low over Riis Beach in Brooklyn, New York'],
#  '849': ['Shots from Galway'],
#  '846': ['Street band'],
#  '847': ['Woman on Vacations with Hat Relaxing -Swimming Pool'],
#  '850': ['Young woman in blue dress stands looking at camera'],
#  '853': ['Woman Exercising Abs on the Floor Mat'],
#  '851': ['Woman wearing charcoal face mask and holding a cosmetic jar'],
#  '848': ["A man's face with a make up"],
#  '855': ['A young businessman in a suit isolated on a white background.'],
#  '857': ['People - Businessman Aspirations - Double Exposure Effect'],
#  '852': ['A woman sits under a tree by a river.'],
#  '856': ['Photographer taking a picture of Pianist'],
#  '854': ['Siem Reap to Battambang'],
#  '858': ['Girl with a sword and tall boots, steakpunk warrior style'],
#  '860': ['A cute young girl doing stretches on a track field.'],
#  '861': ['Old asian man'],
#  '864': ['Two caucasian women in swimwear sunbathing on the beach'],
#  '866': ['Female track athlete at the starting line'],
#  '863': ['Young Man Watching the Sunrise at Rocky Beach'],
#  '862': ['A dancer practices ballet amongst the trees.'],
#  '865': ['Vintage 35m slide photos'],
#  '859': ['cut watermelon on a plate'],
#  '867': ['Asian girl takes photo with a Nikon D7200 DSLR camera - Editorial use'],
#  '869': ["A cute young girl dressed for Saint Patrick's Day."],
#  '871': ['A young businessman talking on a cell phone.'],
#  '870': ['Man looking at camera, wearing black and white makeup, with beard'],
#  '873': ['Some teenagers playing in the water at the beach'],
#  '872': ['A young cowboywearing a brown cowboy hat and brown long sleeve shirt'],
#  '868': ['A woman poses along a wall full of graffiti'],
#  '875': ['Hiker on the mountain ridge - Madeira Island - Portugal'],
#  '876': ['A cute young girl posing with a small dog.'],
#  '878': ['Couple Walking Hand in Hand'],
#  '879': ['People Enjoying the View and Discussing Business'],
#  '880': ['Having Doubts - Drawing of a Man on Blackboard - Illustration'],
#  '877': [' Two Friends Talking and Having Fun'],
#  '881': ['Johnny practices his trade before he becomes a pro.'],
#  '885': ['Woman in glasses carrying files, hands on glasses'],
#  '882': ['Yound woman tries to keep warm.'],
#  '886': ['Illustration of a man jumping full of joy'],
#  '887': ['Getting a little dirty from the colored sands of Lake McConaughy, the girl now has sandy feet!'],
#  '883': ['Young man shouting.'],
#  '884': ['Young man pulling out clothes from washing machine in washaterias'],
#  '889': ['A beautiful young woman exercising with weights.'],
#  '892': ['Close-up portrait of a beautiful girl wearing sunglasses.'],
#  '894': ['Cute Child Showing Thumbs Up'],
#  '893': ['A child basking in the sun wearing pink bikini and eyewear'],
#  '895': ['A beautiful business woman talking on a headset.'],
#  '896': ['hands on the stomach of pregnant woman'],
#  '897': ['Woman poses over white background'],
#  '898': ['deliciously cooked seafood clam shells'],
#  '899': ['A youg woman in a striped shirt stands in a studio shot.'],
#  '902': ['Child taking a picture with DSLR camera at sunset'],
#  '906': ['Young african american model stands in blue dress.'],
#  '900': ['Black & white vintage style portrait of a young child washing her hands in the typical village of Moustiers, Provence, France'],
#  '908': ['Woman with legs crossed stands on tiled road'],
#  '904': ['Politely Holding of the Hands'],
#  '911': ['Young man perusing books at a used book store.'],
#  '907': ['Close up of a man and woman holding coffee mugs on a table with creamer container in the middle'],
#  '910': ['A smart girl with glasses holding a book.'],
#  '909': ['Crowd participating at an indoor event'],
#  '913': ['A beautiful young woman wearing pearls posing on a gray background.'],
#  '903': ['Technology Disruption - The Rise of Artificial Intelligence - Concept with Copyspace'],
#  '915': ['A beautiful young girl playing on a playground with a dog.'],
#  '918': ['Indian villagers with hookah'],
#  '916': ['Person enjoying horse riding in a tourist spot of India'],
#  '917': ['Child with brush painting with aquarel'],
#  '919': ['Cute Kid'],
#  '925': ['A smart girl with glasses reading a book.'],
#  '920': ['Beautiful woman with an axe - Double exposure with Torres del Paine mountains'],
#  '922': ['Three men in black shoes and black trousers on the road'],
#  '921': ['Baby bathing while holding and suckling a yellow duck toy'],
#  '923': ['Toddler looking her younger baby sister in the eyes'],
#  '924': ['Warming Up - Male Athlete Performing Squat Jumps at Sunrise'],
#  '926': ['Dying woman'],
#  '929': ['Happy baby lying on a blanket'],
#  '932': ['A group of blondes and brunettes wearing bikinis of multiple colours posing in knee deep sea water'],
#  '930': ['Young Asian man with a retro microphone'],
#  '928': ['A group of multiethnic students working on project in the classroom'],
#  '927': ['Tattooed Woman - Grunge Noisy Looks\n'],
#  '936': ['Baby trying to eat a banana'],
#  '935': ['Lone Biker on the Road Through Mountains'],
#  '938': ['a woman relaxing'],
#  '937': ['Little Girl Playing with a Ball in the Swimming Pool'],
#  '940': ['Woman and her daugher stand together in nice clothes'],
#  '939': ['Two Cowboys riding across Antelope Island State Park in Utah'],
#  '942': ['Brunette looking at camera, holding bouquet of flowers'],
#  '941': ['Toddler brown eyes - closeup'],
#  '946': ['Brunette looking at camera, standing on a styleized beach'],
#  '944': ['Female Athlete exercise in the park'],
#  '945': ['baby sucking fingers'],
#  '948': ['Up to the Challenge - Woman with Surfboard ready to Surf - Vintage Looks'],
#  '947': ['Close-ups of various conifers.'],
#  '949': ['Children in the Peruvian area of Lake Titicaca enjoy a day outside in the sunlight and greet visitors.'],
#  '951': ['Female Violinist with playing a violin'],
#  '950': ['Young man cycling on the bicycle path'],
#  '957': ['Cute Little Girl Raising Finger - Imagination and Creativity'],
#  '956': ['Woman doing extended hand to toe yoga pose'],
#  '955': ['Chubby hands holding flower'],
#  '954': ['Urban Setting - People in the Street'],
#  '958': ['Young woman pulls one side of her headphones back.'],
#  '961': ['Portrait of seductive woman looking at the camera'],
#  '953': ['Girl showering her head'],
#  '959': ['Attractive young African American woman stands in jeans and a scarf.'],
#  '964': ['Woman in colorful dress stands and listens to music.'],
#  '962': ['A girl sitting in a kiddie pool.'],
#  '960': ['People shopping on crowded pedestrian street in Paris, France.'],
#  '969': ['Sweet baby crawling on carpet'],
#  '965': ['Close-Up of Lovers Legs in the Forest'],
#  '967': ['A model shows off fresh graffiti'],
#  '970': ['Toddler washing her hands and observing hats - old fountain located at the back of the ancient church in Moustiers, Provence, France'],
#  '968': ['Urban Girl - Close-Up of Legs - Ripped Jeans and Sneakers'],
#  '975': ['A pretty young girl pulling on her hair.'],
#  '971': ['Sneakers'],
#  '974': ['A smiling baby sitting under a swingset.'],
#  '977': ['A bread loaf in a basket with red lining'],
#  '972': ['A beautiful red rose and a box of gift wrapped with a blue gift wrapper'],
#  '976': ['Woman Heels'],
#  '982': ['Young woman standing in tall white boots on white background'],
#  '979': ['Yound woman stands, wearing a scarf'],
#  '984': ['Businessman with lightbulb head in front of the computer'],
#  '980': ['Attractive young African American woman in a scarf.'],
#  '983': ['A young businessman making a thumbs up gesture with a white background.'],
#  '981': ['Fishermen hauling their fishing boat after sailing it in the early morning waters of a Zambales Province beach in the Philippines.'],
#  '985': ['A woman in fishnet stockings stands on a train track.'],
#  '986': ['A young man wearing a red hooded shirt and black shades'],
#  '988': ['Zombie'],
#  '993': ['Craftsman is sculpting a wooden owl'],
#  '989': ["Johnny loves cats and his Aunt Heidi's farm is full of them."],
#  '996': ['People at Underground Subway Station Climbing Stairs - Blurry Looks'],
#  '994': ['Reflection of people walking'],
#  '997': ['A cute young girl wearing a peace symbol t-shirt.'],
#  '995': ['Black and White Costumed Clown'],
#  '991': ['Running an Ultramarathon - Runner on Monument Valley'],
#  '1000': ['puerto gallera resort view'],
#  '998': ['Man in a denim and white t-shirt standing with his arms folded'],
#  '1002': ['Surfer - Surfing lifestyle concept\n'],
#  '1004': ['Woman in red dress in spotlight looks up.'],
#  '1003': ['Little Girl with Sad Eyes'],
#  '1006': ['Businessman with Dollar Kite Burning in Flames'],
#  '1011': ['Arab woman with veil'],
#  '1010': ['Mommy and Johnny enjoy some quiet time.'],
#  '1007': ['Big group of happy school kids mugging for the camera'],
#  '1014': ['Young Asian man standing in tee shirt, looking at camera'],
#  '1013': ['Portrait of woman with floral headpiece wearing blue dress'],
#  '1008': ['Businessman facing stairs with Earth globe'],
#  '1016': ['Arabic old man'],
#  '1017': ['The Muddy volcanoes landscape from Buzau Romania'],
#  '1019': ['Hit the Road - A Man Prepares to Run - Running'],
#  '1015': ['Closeup of a beautiful woman posing in a blue skirt on a bed.'],
#  '1024': ['In order to spread more awareness towards the body painting arts, I have chosen to share some of my work as free stock photography.\nPlease make sure and credit the following if you use my images:\nModels: Cherry Blossom and Zach Anon\nPhotography and Body Painting by: Bryan Crump aka #crumpeffect\nBodypaint/Makeup used: Snazaroo and Mehron\nStudio: Facemakers'],
#  '1022': ['Kid Taking Pictures of the Planets and the Moon'],
#  '1027': ['Colorful Christmas gifts and christmas decorations'],
#  '1029': ['Young woman in orange pants and blue top waters.'],
#  '1030': ['A picture of two high rise buildings and a clear blue sky back drop'],
#  '1033': ['HDR shot of park in Calgary Canada.'],
#  '1031': ['Portrait of glamorous woman with false eyelashes'],
#  '1036': ['Young cool guy in a leather vest'],
#  '1034': ['Two old, arthritis-riddled hands'],
#  '1035': ['A cute young girl drinking water on a track field.'],
#  '1032': ['Portrait of a Young Woman - Colorized'],
#  '1037': ['Child posing on a field of lavenders in Provence, France'],
#  '1042': ['Traditional Christmas Decorations'],
#  '1040': ['Father Holding His Baby on the Beach'],
#  '1041': ['Girl on the Beach at Sunset - Double Exposure Effect'],
#  '1045': ['A young woman wearing a blus turtle neck with a red electric guitar'],
#  '1044': ['Baby Sleeping'],
#  '1043': ['A girl walks along the beach as the waves lap at her bare feet and seagulls fly overhead.'],
#  '1049': ['A pretty young girl talking on a cell phone.'],
#  '1050': ['A couple sitting on a bench overlooking the ocean.'],
#  '1047': ['Asian man in fedora hat playing the saxophone.'],
#  '1051': ['Friends'],
#  '1055': ['A man in a cowboy hat and makeshift tank top with cut sleeve stands by a pickup truck in this black and white shot.'],
#  '1058': ['Girl with a sword and tall boots, steakpunk warrior style, versino two.'],
#  '1059': ['Young woman ready to sing in to microphone'],
#  '1061': ['A cute young girl holding Easter eggs.'],
#  '1053': ['View of feet on the train tracks.'],
#  '1054': ['Business Agreement - Handshake Confirmation'],
#  '1056': ['People standing in a queue for their orders'],
#  '1052': ['Priest standing in church'],
#  '1057': ['Man in modern stylish clothes stands in front of a neutral background'],
#  '1064': ['Newborn Baby Sleeping - Smooth Colors'],
#  '1065': ['Child looking out on the pier'],
#  '1066': ['Lone Young Girl at Sunset Looking at the Far Horizon'],
#  '1069': ['A beautiful young business woman posing on a white background.'],
#  '1071': ['Child and Barbed Wire'],
#  '1074': ['A beautiful business woman looking over a book.'],
#  '1075': ['Woman Practicing Yoga by the Ocean - Metal Toned'],
#  '1081': ['Young man dressed in very warm clothes'],
#  '1083': ['Older man holding a large skull'],
#  '1076': ['Young man listening to music on MP3 player with head set in an airplane'],
#  '1078': ['Delicious yellow egg tarts on baking pans'],
#  '1079': ['Young bearded male wearing black turtleneck top and eyeglasses posing at the street'],
#  '1086': ['Woman Feeling Blue - Depression - Depressed - Anxiety'],
#  '1070': ['Close brothers and friend on the pier'],
#  '1082': ['Intense man looking at camera'],
#  '1090': ['A young businessman making a thumbs up gesture.'],
#  '1085': ['Blonde Young Woman In Red Sports Bra Doing Abs Crunches In Gym'],
#  '1084': ['Angry child on the beach closeup'],
#  '1089': ['Crowd gathered around the stage of an underground concert.'],
#  '1088': ['A beautiful young woman posing against a tree by a lake.'],
#  '1092': ['Father bathing with his baby daughter at sunset in Praia da Marinha - Algarve - Portugal'],
#  '1077': ['Young african american woman ready to sing.'],
#  '1095': ['A beautiful young girl holding a cell phone.'],
#  '1093': ['Taken at Walt Disney World in Orlando, Florida'],
#  '1096': ['Eat More Fruit - Woman and Assorted Fruit'],
#  '1091': ['Career Development - Career Path - Where To Go From Here'],
#  '1094': ['Cute Kid with Football'],
#  '1097': ['Excited woman dancing and listening music with headphones and smart phone with hair moving, isolated on yellow background'],
#  '1100': ['Summer beachgoers - people on the beach in Odeceixe Beach in southern Portugal'],
#  '1098': ['Woman standing on the road with a plane flying over'],
#  '1099': ['Sweet girl relaxing on the grass - Top View'],
#  '1104': ['Asian man looking at camera, seated.'],
#  '1103': ['Photo of a young man posing for pictures prior to prom.'],
#  '1101': ['Boy pointing a handgun'],
#  '1102': ['A young woman wearing a blue turtle neck with a red electric guitar'],
#  '1106': ['Portrait of Dreamy Woman on Autumn Leaves'],
#  '1108': ['Illustration of woman dieting by eating salad.'],
#  '1105': ['A pretty young girl with a thoughtful expression.'],
#  '1107': ['Young man in white shirt and black tie sitting cross-legged dreamily looks out the window during a break in office hours'],
#  '1111': ['Cute newborn baby sleeps during Christmas'],
#  '1112': ['Two young sisters facing each other - a toddler and a baby'],
#  '1114': ['Children eating icecream in Summer'],
#  '1113': ['Get Set and Go Fast - A Runner at Sunrise'],
#  '1110': ['Happy family on the beach'],
#  '1116': ['A close up pose of a woman under a tree.'],
#  '1117': ['Girl washing her hair'],
#  '1118': ['The welder is joining steel beams.'],
#  '1120': ['A beautiful business woman talking on a cell phone.'],
#  '1121': ['A beautiful business woman holding a blank business card.'],
#  '1123': ['Asian man in fedora hat isolated on white'],
#  '1122': ['Woman wearing spectacles splashed with water'],
#  '1124': ['An unfinished high rise building'],
#  '1131': ['A cute young girl making a heart symbol.'],
#  '1127': ['A beautiful young girl posing outdoors.'],
#  '1129': ['Young Man Smoking - Colorized'],
#  '1128': ['Young woman forming circles with fingers around eyes'],
#  '1125': ['A woman poses in front of a camera on the top of a bridge.'],
#  '1135': ['A boy playing in a calm but cold Adirondack Lake in late summer.'],
#  '1133': ['Young Woman In White Bikini And Sunglasses Lying On Sand On The Beach'],
#  '1139': ['A beautiful young woman dressed in business attire posing near a building.\n'],
#  '1134': ['Young Adult Man sitting on office chair near the window of room and looking out'],
#  '1132': ['a fish in a large aquarium'],
#  '1141': ['Couple in Love Reading Outdoors - Washed-out Effect'],
#  '1138': ['Small girl dancing in Peruvian Parade'],
#  '1143': ['Black & white close-up image of a thoughtful young ballerina with a band aid on the elbow'],
#  '1137': ['Soft homeless Easter bunny outside the door of a house with a message'],
#  '1140': ['Finger pointing'],
#  ...}

# %%
len(mapping)
# Out:
# 2054

# %%
mapping['6']
# Out:
# ['A beautiful young girl posing with a gray background.']

# %% [markdown]
# ## Preprocessing the text data

# %%
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            # take one caption at a time
            caption = captions[i]
            # preprocessing steps
            # convert to lowercase
            caption = caption.lower()
            # delete digits, special chars, etc.,
            caption = caption.replace('।', '')
            # delete additional spaces
            caption = caption.replace('\s+', ' ')
            # add  tags to the caption
            caption = " ".join([word for word in caption.split() if len(word)>1])
            captions[i] = caption

# %%
# before preprocess of text
mapping['6']
# Out:
# ['a beautiful young girl posing with a gray background.']

# %%
# preprocess the text
clean(mapping)

# %%
# after preprocess of text
mapping['6']
# Out:
# ['beautiful young girl posing with gray background.']

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
len(all_captions)
# Out:
# 2054

# %%
all_captions[:10]
# Out:
# ['beautiful young girl posing on white background.',
#  'one hand pointing, finger out, thumb up',
#  'beautiful young girl posing with gray background.',
#  'medical stitches puncture wound closed up',
#  'happy couple',
#  'young girl dancing on stage in tutu this image was shot at high iso, only use it as is, noise removal software was used.',
#  'man thinking with white mask',
#  'businessman with lightbulb head thinking process and ideas in business context',
#  'mother and baby in swimming pool',
#  'my hand compared to ancient handprints of anasazi tribes']

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 2942

# %%
# get maximum length of the caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 72

# %% [markdown]
# ## Train Test Split

# %%
image_ids = list(mapping.keys())
split = int(len(image_ids) * 0.98)
train = image_ids[:split]
test = image_ids[split:]

# %%
len(test),len(train)
# Out:
# (42, 2012)

# %%
# create data generator to get data in batch (avoids session crash)
def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    # loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            # process each caption
            for caption in captions:
                # encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    # split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    # encode output sequence
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]

                    # store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield [X1, X2], y
                X1, X2, y = list(), list(), list()
                n = 0

# %% [markdown]
# ## Model Creation

# %%
# encoder model
# image feature layers
inputs1 = Input(shape=(4096,))
fe1 = Dropout(0.2)(inputs1)
fe2 = Dense(512, activation='relu')(fe1)
# sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 512, mask_zero=True)(inputs2)
se2 = Dropout(0.4)(se1)
se3 = LSTM(512)(se2)

# decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(512, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# plot the model
plot_model(model, show_shapes=True)

# %%
# train the model
epochs = 40
batch_size = 32
steps = len(train) // batch_size

for i in range(epochs):
    # create data generator
    generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
    # fit for one epoch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# 62/62 [==============================] - 358s 6s/step - loss: 6.5122 - accuracy: 0.0550
# 62/62 [==============================] - 337s 5s/step - loss: 5.6173 - accuracy: 0.0798
# 62/62 [==============================] - 333s 5s/step - loss: 5.0006 - accuracy: 0.1058
# 62/62 [==============================] - 331s 5s/step - loss: 4.3412 - accuracy: 0.1422
# 62/62 [==============================] - 333s 5s/step - loss: 3.7682 - accuracy: 0.1792
# 62/62 [==============================] - 333s 5s/step - loss: 3.4004 - accuracy: 0.2197
# 62/62 [==============================] - 333s 5s/step - loss: 3.0867 - accuracy: 0.2608
# 62/62 [==============================] - 334s 5s/step - loss: 2.7466 - accuracy: 0.3148
# 62/62 [==============================] - 332s 5s/step - loss: 2.4773 - accuracy: 0.3690
# 57/62 [==========================>...] - ETA: 26s - loss: 2.2492 - accuracy: 0.4081

# %%
# save the model
model.save(WORKING_DIR+'/best_model.h5')

# %% [markdown]
# ## Model Creation

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    # add start tag for generation process
    in_text = 'startseq'
    # iterate over the max length of sequence
    for i in range(max_length):
        # encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        # pad the sequence
        sequence = pad_sequences([sequence], max_length)
        # predict next word
        yhat = model.predict([image, sequence], verbose=0)
        # get index with high probability
        yhat = np.argmax(yhat)
        # convert index to word
        word = idx_to_word(yhat, tokenizer)
        # stop if word not found
        if word is None:
            break
        # append word as input for generating next word
        in_text += " " + word
        # stop if we reach end tag
        if word == 'endseq':
            break

    return in_text

# %%
from nltk.translate.bleu_score import corpus_bleu
# validate with test data
actual, predicted = list(), list()

for key in tqdm(test):
    # get actual caption
    captions = mapping[key]
    # predict the caption for image
    y_pred = predict_caption(model, features[key], tokenizer, max_length)
    # split into words
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    # append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)

# calcuate BLEU score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))

# %% [markdown]
# ## Results

# %%
from PIL import Image
import matplotlib.pyplot as plt
def generate_caption(image_name):
    # load the image
    # image_name = "6000.jpg"
    image_id = image_name.split('.')[0]
    image_id =image_id.split('_')[1]
    img_path = os.path.join(path,  image_name)
    image = Image.open(img_path)
    captions = mapping[image_id]
    print('---------------------Actual---------------------')
    for caption in captions:
        print(caption)
    # predict the caption
    y_pred = predict_caption(model, features[image_id], tokenizer, max_length)
    print('--------------------Predicted--------------------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("image_2454.jpg")

# %%
generate_caption("6020.jpg")

# %%
generate_caption("1003.jpg")

# %%
generate_caption("1015.jpg")

# %%
generate_caption("6050.jpg")

# %%
generate_caption("600.jpg")

# %%
generate_caption("6005.jpg")

# %%
generate_caption("6025.jpg")
